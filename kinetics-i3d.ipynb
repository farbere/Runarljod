# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# <h3>Kinetics-i3d video action classifier</h3>
#
# See https://github.com/deepmind/kinetics-i3d

# %%
# after i3d.py

pad_same = "SAME"
pad_valid = "VALID"

class Unit3D(tf.Module):
    #Basic unit containing Conv3D + BatchNorm + non-linearity.

    def __init__(self, output_channels,
                   kernel_shape = [1,1,1],
                   stride=[1, 1, 1],
                   activation_fn=tf.nn.relu,
                   use_batch_norm=True,
                   use_bias=False,
                   name='unit_3d'):
        super(Unit3D, self).__init__()
        self._output_channels = output_channels
        self._kernel_shape = kernel_shape
        self._padding = pad_same
        self._stride = [1] + stride + [1]
        self._use_batch_norm = use_batch_norm
        self._activation_fn = activation_fn
        self._use_bias = use_bias
        self._name = name

        # vardict refers to a global dictionary of tf.Variables loaded from the file containing the weights
        if self._use_batch_norm:
            self.bn_beta = vardict[self._name + "/batch_norm/beta"]
            self.bn_moving_mean = vardict[self._name + "/batch_norm/moving_mean"]
            self.bn_moving_variance = vardict[self._name + "/batch_norm/moving_variance"]
        self.conv_w = vardict[self._name + "/conv_3d/w"]
        if self._use_bias:
            self.conv_b = vardict[self._name+"/conv_3d/b"]
        
    def __call__(self, inputs, is_training):
         # input shape is [batch, depth, height, width, channels]
        net = tf.nn.conv3d(inputs, filters=self.conv_w, strides=self._stride, padding=self._padding)
        if self._use_bias:
            net = tf.nn.bias_add(net, self.conv_b)
        if self._use_batch_norm:
            net = tf.nn.batch_normalization(net, 
                                            self.bn_moving_mean, 
                                            self.bn_moving_variance, 
                                            self.bn_beta, 
                                            scale=1, 
                                            variance_epsilon=0.01)
        if self._activation_fn is not None:
            net = self._activation_fn(net)
        return net

class InceptionI3d(tf.Module):
#  """Inception-v1 I3D architecture.

#  The model is introduced in:

#    Quo Vadis, Action Recognition? A New Model and the Kinetics Dataset
#    Joao Carreira, Andrew Zisserman
#    https://arxiv.org/pdf/1705.07750v1.pdf.

#  See also the Inception architecture, introduced in:

#    Going deeper with convolutions
#    Christian Szegedy, Wei Liu, Yangqing Jia, Pierre Sermanet, Scott Reed,
#    Dragomir Anguelov, Dumitru Erhan, Vincent Vanhoucke, Andrew Rabinovich.
#    http://arxiv.org/pdf/1409.4842v1.pdf.
#  """

  # Endpoints of the model in order. During construction, all the endpoints up
  # to a designated `final_endpoint` are returned in a dictionary as the
  # second return value.
    VALID_ENDPOINTS = (
      'Conv3d_1a_7x7',
      'MaxPool3d_2a_3x3',
      'Conv3d_2b_1x1',
      'Conv3d_2c_3x3',
      'MaxPool3d_3a_3x3',
      'Mixed_3b',
      'Mixed_3c',
      'MaxPool3d_4a_3x3',
      'Mixed_4b',
      'Mixed_4c',
      'Mixed_4d',
      'Mixed_4e',
      'Mixed_4f',
      'MaxPool3d_5a_2x2',
      'Mixed_5b',
      'Mixed_5c',
      'Logits',
      'Predictions',
  )
    
    # In the paper referenced above, notations are made of the receptive field after each pooling layer, i.e. the
    # size of the input data that each of its outputs depends on. They are (time is the first dim listed):
    #   MaxPool3d_2a_3x3   7x11x11
    #   MaxPool3d_3a_3x3   11x27x27
    #   MaxPool3d_4a_3x3   23x75x75
    #   MaxPool3d_5a_2x2   59x219x219
    #   AvgPool3d_2x7x7    99x539x539
    # The AvgPool layer is immediately prior to the logits (which are linear combinations of its outputs).
    # Since the net uses only convolutional layers the dimensions of its input are not fixed (they can even vary
    # between calls, since the net calls tf.nn.conv3d directly rather than keras.layers.Conv3D).
    

    def __init__(self, var_prefix='RGB', num_classes=400, spatial_squeeze=True,
               final_endpoint='Logits', name='inception_i3d'):
#    """Initializes I3D model instance.

#    Args:
#      num_classes: The number of outputs in the logit layer (default 400, which
#          matches the Kinetics dataset).
#      spatial_squeeze: Whether to squeeze the spatial dimensions for the logits
#          before returning (default True).
#      final_endpoint: The model contains many possible endpoints.
#          `final_endpoint` specifies the last endpoint for the model to be built
#          up to. In addition to the output at `final_endpoint`, all the outputs
#          at endpoints up to `final_endpoint` will also be returned, in a
#          dictionary. `final_endpoint` must be one of
#          InceptionI3d.VALID_ENDPOINTS (default 'Logits').
#      name: A string (optional). The name of this module.
#    Raises:
#      ValueError: if `final_endpoint` is not recognized.
#    """

        if final_endpoint not in self.VALID_ENDPOINTS:
            raise ValueError('Unknown final endpoint %s' % final_endpoint)

        super(InceptionI3d, self).__init__(name=name)
        self._num_classes = num_classes
        self._spatial_squeeze = spatial_squeeze
        self._final_endpoint = final_endpoint
        self._var_prefix = var_prefix

        # except for the first and last entries here all this (output channels and kernel shape) is already implicit 
        # in the weights passed to the modules. the important part is the correspondence between modules and the 
        # names of variables contained in the checkpoint data
        arg_dict = {'Conv3d_1a_7x7' : {'output_channels': 64, 'kernel_shape' : [7,7,7], 'stride' : [2,2,2]}, 
                     'Conv3d_2b_1x1' : {'output_channels' : 64, 'kernel_shape' : [1, 1, 1]},
                     'Conv3d_2c_3x3' : {'output_channels' : 192, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_3b/Branch_0/Conv3d_0a_1x1' : {'output_channels' : 64, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_3b/Branch_1/Conv3d_0a_1x1' : {'output_channels' : 96, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_3b/Branch_1/Conv3d_0b_3x3' : {'output_channels' : 128, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_3b/Branch_2/Conv3d_0a_1x1' : {'output_channels' : 16, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_3b/Branch_2/Conv3d_0b_3x3' : {'output_channels' : 32, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_3b/Branch_3/Conv3d_0b_1x1' : {'output_channels' : 32, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_3c/Branch_0/Conv3d_0a_1x1' : {'output_channels' : 128, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_3c/Branch_1/Conv3d_0a_1x1' : {'output_channels' : 128, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_3c/Branch_1/Conv3d_0b_3x3' : {'output_channels' : 192, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_3c/Branch_2/Conv3d_0a_1x1' : {'output_channels' : 32, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_3c/Branch_2/Conv3d_0b_3x3' : {'output_channels' : 96, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_3c/Branch_3/Conv3d_0b_1x1' : {'output_channels' : 64, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4b/Branch_0/Conv3d_0a_1x1' : {'output_channels' : 192, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4b/Branch_1/Conv3d_0a_1x1' : {'output_channels' : 96, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4b/Branch_1/Conv3d_0b_3x3' : {'output_channels' : 208, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_4b/Branch_2/Conv3d_0a_1x1' : {'output_channels' : 16, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4b/Branch_2/Conv3d_0b_3x3' : {'output_channels' : 48, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_4b/Branch_3/Conv3d_0b_1x1' : {'output_channels' : 64, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4c/Branch_0/Conv3d_0a_1x1' : {'output_channels' : 160, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4c/Branch_1/Conv3d_0a_1x1' : {'output_channels' : 112, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4c/Branch_1/Conv3d_0b_3x3' : {'output_channels' : 224, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_4c/Branch_2/Conv3d_0a_1x1' : {'output_channels' : 24, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4c/Branch_2/Conv3d_0b_3x3' : {'output_channels' : 64, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_4c/Branch_3/Conv3d_0b_1x1' : {'output_channels' : 64, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4d/Branch_0/Conv3d_0a_1x1' : {'output_channels' : 128, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4d/Branch_1/Conv3d_0a_1x1' : {'output_channels' : 128, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4d/Branch_1/Conv3d_0b_3x3' : {'output_channels' : 256, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_4d/Branch_2/Conv3d_0a_1x1' : {'output_channels' : 24, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4d/Branch_2/Conv3d_0b_3x3' : {'output_channels' : 64, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_4d/Branch_3/Conv3d_0b_1x1' : {'output_channels' : 64, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4e/Branch_0/Conv3d_0a_1x1' : {'output_channels' : 112, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4e/Branch_1/Conv3d_0a_1x1' : {'output_channels' : 144, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4e/Branch_1/Conv3d_0b_3x3' : {'output_channels' : 288, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_4e/Branch_2/Conv3d_0a_1x1' : {'output_channels' : 32, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4e/Branch_2/Conv3d_0b_3x3' : {'output_channels' : 64, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_4e/Branch_3/Conv3d_0b_1x1' : {'output_channels' : 64, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4f/Branch_0/Conv3d_0a_1x1' : {'output_channels' : 256, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4f/Branch_1/Conv3d_0a_1x1' : {'output_channels' : 160, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4f/Branch_1/Conv3d_0b_3x3' : {'output_channels' : 320, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_4f/Branch_2/Conv3d_0a_1x1' : {'output_channels' : 32, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_4f/Branch_2/Conv3d_0b_3x3' : {'output_channels' : 128, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_4f/Branch_3/Conv3d_0b_1x1' : {'output_channels' : 128, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_5b/Branch_0/Conv3d_0a_1x1' : {'output_channels' : 256, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_5b/Branch_1/Conv3d_0a_1x1' : {'output_channels' : 160, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_5b/Branch_1/Conv3d_0b_3x3' : {'output_channels' : 320, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_5b/Branch_2/Conv3d_0a_1x1' : {'output_channels' : 32, 'kernel_shape' : [1, 1, 1]},
                    # typo here: in other modules the name is Branch2/Conv3d_0b_3x3 !
                     'Mixed_5b/Branch_2/Conv3d_0a_3x3' : {'output_channels' : 128, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_5b/Branch_3/Conv3d_0b_1x1' : {'output_channels' : 128, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_5c/Branch_0/Conv3d_0a_1x1' : {'output_channels' : 384, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_5c/Branch_1/Conv3d_0a_1x1' : {'output_channels' : 192, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_5c/Branch_1/Conv3d_0b_3x3' : {'output_channels' : 384, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_5c/Branch_2/Conv3d_0a_1x1' : {'output_channels' : 48, 'kernel_shape' : [1, 1, 1]},
                     'Mixed_5c/Branch_2/Conv3d_0b_3x3' : {'output_channels' : 128, 'kernel_shape' : [3, 3, 3]},
                     'Mixed_5c/Branch_3/Conv3d_0b_1x1' : {'output_channels' : 128, 'kernel_shape' : [1, 1, 1]},
                     'Logits/Conv3d_0c_1x1' : {'output_channels' : self._num_classes, 'kernel_shape' : [1, 1, 1],
                                              'activation_fn' : None, 'use_batch_norm' : False, 'use_bias' : True}
                    }
        
        self.module_dict = {}
        model_prefix = self._var_prefix + "/" + self.name + "/" 
        for module_name in list(arg_dict.keys()):
            self.module_dict[module_name] = Unit3D(**arg_dict[module_name],
                                              name = model_prefix+module_name)

    def __call__(self, inputs, is_training, dropout_prob=0.0):
#    """Connects the model to inputs.

#    Args:
#      inputs: Inputs to the model, which should have dimensions
#          `batch_size` x `num_frames` x 224 x 224 x `num_channels`.
#      is_training: whether to use training mode for snt.BatchNorm (boolean).
#      dropout_prob: Probability for the tf.nn.dropout layer (float in
#          [0, 1)).

#    Returns:
#      A tuple consisting of:
#        1. Network output at location `self._final_endpoint`.
#        2. Dictionary containing all endpoints up to `self._final_endpoint`,
#           indexed by endpoint name.

#    Raises:
#      ValueError: if `self._final_endpoint` is not recognized.
#    """
        if self._final_endpoint not in self.VALID_ENDPOINTS:
            raise ValueError('Unknown final endpoint %s' % self._final_endpoint)

        net = inputs
        end_points = {}
        end_point = 'Conv3d_1a_7x7'        
        net = self.module_dict[end_point](net, is_training=is_training)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points
        
        end_point = 'MaxPool3d_2a_3x3'
        net = tf.nn.max_pool3d(net, ksize=[1, 1, 3, 3, 1], strides=[1, 1, 2, 2, 1],
                               padding=pad_same, name=end_point)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points
        end_point = 'Conv3d_2b_1x1'
        net = self.module_dict[end_point](net, is_training=is_training)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points
        end_point = 'Conv3d_2c_3x3'
        net = self.module_dict[end_point](net, is_training=is_training)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points
        end_point = 'MaxPool3d_3a_3x3'
        net = tf.nn.max_pool3d(net, ksize=[1, 1, 3, 3, 1], strides=[1, 1, 2, 2, 1],
                               padding=pad_same, name=end_point)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points

        end_point = 'Mixed_3b'
        branch_0 = self.module_dict[end_point+'/Branch_0/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0b_3x3'](branch_1, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0b_3x3'](branch_2, is_training=is_training)
        branch_3 = tf.nn.max_pool3d(net, ksize=[1, 3, 3, 3, 1],
                                            strides=[1, 1, 1, 1, 1], padding=pad_same,
                                            name='MaxPool3d_0a_3x3')
        branch_3 = self.module_dict[end_point+'/Branch_3/Conv3d_0b_1x1'](branch_3, is_training=is_training)

        net = tf.concat([branch_0, branch_1, branch_2, branch_3], 4)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points

        end_point = 'Mixed_3c'
        branch_0 = self.module_dict[end_point+'/Branch_0/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0b_3x3'](branch_1, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0b_3x3'](branch_2, is_training=is_training)
        branch_3 = tf.nn.max_pool3d(net, ksize=[1, 3, 3, 3, 1],
                                            strides=[1, 1, 1, 1, 1], padding=pad_same,
                                            name='MaxPool3d_0a_3x3')
        branch_3 = self.module_dict[end_point+'/Branch_3/Conv3d_0b_1x1'](branch_3, is_training=is_training)
        net = tf.concat([branch_0, branch_1, branch_2, branch_3], 4)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points

        end_point = 'MaxPool3d_4a_3x3'
        net = tf.nn.max_pool3d(net, ksize=[1, 3, 3, 3, 1], strides=[1, 2, 2, 2, 1],
                               padding=pad_same, name=end_point)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points

        end_point = 'Mixed_4b'
        branch_0 = self.module_dict[end_point+'/Branch_0/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0b_3x3'](branch_1, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0b_3x3'](branch_2, is_training=is_training)
        branch_3 = tf.nn.max_pool3d(net, ksize=[1, 3, 3, 3, 1],
                                            strides=[1, 1, 1, 1, 1], padding=pad_same,
                                            name='MaxPool3d_0a_3x3')
        branch_3 = self.module_dict[end_point+'/Branch_3/Conv3d_0b_1x1'](branch_3, is_training=is_training)
        net = tf.concat([branch_0, branch_1, branch_2, branch_3], 4)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points

        end_point = 'Mixed_4c'
        branch_0 = self.module_dict[end_point+'/Branch_0/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0b_3x3'](branch_1, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0b_3x3'](branch_2, is_training=is_training)
        branch_3 = tf.nn.max_pool3d(net, ksize=[1, 3, 3, 3, 1],
                                            strides=[1, 1, 1, 1, 1], padding=pad_same,
                                            name='MaxPool3d_0a_3x3')
        branch_3 = self.module_dict[end_point+'/Branch_3/Conv3d_0b_1x1'](branch_3, is_training=is_training)
        net = tf.concat([branch_0, branch_1, branch_2, branch_3], 4)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points

        end_point = 'Mixed_4d'
        branch_0 = self.module_dict[end_point+'/Branch_0/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0b_3x3'](branch_1, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0b_3x3'](branch_2, is_training=is_training)
        branch_3 = tf.nn.max_pool3d(net, ksize=[1, 3, 3, 3, 1],
                                            strides=[1, 1, 1, 1, 1], padding=pad_same,
                                            name='MaxPool3d_0a_3x3')
        branch_3 = self.module_dict[end_point+'/Branch_3/Conv3d_0b_1x1'](branch_3, is_training=is_training)
        net = tf.concat([branch_0, branch_1, branch_2, branch_3], 4)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points

        end_point = 'Mixed_4e'
        branch_0 = self.module_dict[end_point+'/Branch_0/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0b_3x3'](branch_1, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0b_3x3'](branch_2, is_training=is_training)
        branch_3 = tf.nn.max_pool3d(net, ksize=[1, 3, 3, 3, 1],
                                            strides=[1, 1, 1, 1, 1], padding=pad_same,
                                            name='MaxPool3d_0a_3x3')
        branch_3 = self.module_dict[end_point+'/Branch_3/Conv3d_0b_1x1'](branch_3, is_training=is_training)
        net = tf.concat([branch_0, branch_1, branch_2, branch_3], 4)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points

        end_point = 'Mixed_4f'
        branch_0 = self.module_dict[end_point+'/Branch_0/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0b_3x3'](branch_1, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0b_3x3'](branch_2, is_training=is_training)
        branch_3 = tf.nn.max_pool3d(net, ksize=[1, 3, 3, 3, 1],
                                            strides=[1, 1, 1, 1, 1], padding=pad_same,
                                            name='MaxPool3d_0a_3x3')
        branch_3 = self.module_dict[end_point+'/Branch_3/Conv3d_0b_1x1'](branch_3, is_training=is_training)
        net = tf.concat([branch_0, branch_1, branch_2, branch_3], 4)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points

        end_point = 'MaxPool3d_5a_2x2'
        net = tf.nn.max_pool3d(net, ksize=[1, 2, 2, 2, 1], strides=[1, 2, 2, 2, 1],
                               padding=pad_same, name=end_point)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points

        end_point = 'Mixed_5b'
        branch_0 = self.module_dict[end_point+'/Branch_0/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0b_3x3'](branch_1, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0a_1x1'](net, is_training=is_training)
        # typo here: in other modules the name is Branch2/Conv3d_0b_3x3 !
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0a_3x3'](branch_2, is_training=is_training)
        branch_3 = tf.nn.max_pool3d(net, ksize=[1, 3, 3, 3, 1],
                                            strides=[1, 1, 1, 1, 1], padding=pad_same,
                                            name='MaxPool3d_0a_3x3')
        branch_3 = self.module_dict[end_point+'/Branch_3/Conv3d_0b_1x1'](branch_3, is_training=is_training)
        net = tf.concat([branch_0, branch_1, branch_2, branch_3], 4)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points

        end_point = 'Mixed_5c'
        branch_0 = self.module_dict[end_point+'/Branch_0/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_1 = self.module_dict[end_point+'/Branch_1/Conv3d_0b_3x3'](branch_1, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0a_1x1'](net, is_training=is_training)
        branch_2 = self.module_dict[end_point+'/Branch_2/Conv3d_0b_3x3'](branch_2, is_training=is_training)
        branch_3 = tf.nn.max_pool3d(net, ksize=[1, 3, 3, 3, 1],
                                            strides=[1, 1, 1, 1, 1], padding=pad_same,
                                            name='MaxPool3d_0a_3x3')
        branch_3 = self.module_dict[end_point+'/Branch_3/Conv3d_0b_1x1'](branch_3, is_training=is_training)
        net = tf.concat([branch_0, branch_1, branch_2, branch_3], 4)
        end_points[end_point] = net
        if self._final_endpoint == end_point: return net, end_points

        end_point = 'Logits'
        net = tf.nn.avg_pool3d(net, ksize=[1, 2, 7, 7, 1],
                                 strides=[1, 1, 1, 1, 1], padding=pad_valid)
        net = tf.nn.dropout(net, dropout_prob)
        logits = self.module_dict[end_point+'/Conv3d_0c_1x1'](net, is_training=is_training)
        if self._spatial_squeeze:
            logits = tf.squeeze(logits, [2, 3], name='SpatialSqueeze')
        averaged_logits = tf.reduce_mean(logits, axis=1)
        end_points[end_point] = averaged_logits
        if self._final_endpoint == end_point: return averaged_logits, end_points

        end_point = 'Predictions'
        predictions = tf.nn.softmax(averaged_logits)
        end_points[end_point] = predictions
        return predictions, end_points

# %%
# after evaluate_sample.py

_SAMPLE_VIDEO_FRAMES = 79
_SAMPLE_PATHS = {
    'rgb': 'i3d/data/v_CricketShot_g04_c01_rgb.npy',
    'flow': 'i3d/data/v_CricketShot_g04_c01_flow.npy',
}

_CHECKPOINT_PATHS = {
    'rgb': 'i3d/data/checkpoints/rgb_scratch/model.ckpt',
    'rgb600': 'i3d/data/checkpoints/rgb_scratch_kin600/model.ckpt',
    'flow': 'i3d/data/checkpoints/flow_scratch/model.ckpt',
    'rgb_imagenet': 'i3d/data/checkpoints/rgb_imagenet/model.ckpt',
    'flow_imagenet': 'i3d/data/checkpoints/flow_imagenet/model.ckpt',
}

_LABEL_MAP_PATH = 'i3d/data/label_map.txt'
_LABEL_MAP_PATH_600 = 'i3d/data/label_map_600.txt'
kinetics_classes = [x.strip() for x in open(_LABEL_MAP_PATH)]

# if you turn this on, tf will treat all the weights of this network (about 25 million floats altogether) as trainable
fine_tuning = False

# %%
# this list has the names of all the weights in the Flow net and their shapes
flow_varlist = tf.train.list_variables(_CHECKPOINT_PATHS['flow_imagenet'])
flow_varlist
# Out:
# [('Flow/inception_i3d/Conv3d_1a_7x7/batch_norm/beta', [64]),
#  ('Flow/inception_i3d/Conv3d_1a_7x7/batch_norm/moving_mean', [64]),
#  ('Flow/inception_i3d/Conv3d_1a_7x7/batch_norm/moving_variance', [64]),
#  ('Flow/inception_i3d/Conv3d_1a_7x7/conv_3d/w', [7, 7, 7, 2, 64]),
#  ('Flow/inception_i3d/Conv3d_2b_1x1/batch_norm/beta', [64]),
#  ('Flow/inception_i3d/Conv3d_2b_1x1/batch_norm/moving_mean', [64]),
#  ('Flow/inception_i3d/Conv3d_2b_1x1/batch_norm/moving_variance', [64]),
#  ('Flow/inception_i3d/Conv3d_2b_1x1/conv_3d/w', [1, 1, 1, 64, 64]),
#  ('Flow/inception_i3d/Conv3d_2c_3x3/batch_norm/beta', [192]),
#  ('Flow/inception_i3d/Conv3d_2c_3x3/batch_norm/moving_mean', [192]),
#  ('Flow/inception_i3d/Conv3d_2c_3x3/batch_norm/moving_variance', [192]),
#  ('Flow/inception_i3d/Conv3d_2c_3x3/conv_3d/w', [3, 3, 3, 64, 192]),
#  ('Flow/inception_i3d/Logits/Conv3d_0c_1x1/conv_3d/b', [400]),
#  ('Flow/inception_i3d/Logits/Conv3d_0c_1x1/conv_3d/w', [1, 1, 1, 1024, 400]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [64]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [64]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [64]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 192, 64]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [96]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [96]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [96]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 192, 96]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [128]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [128]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [128]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 96, 128]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [16]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [16]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [16]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 192, 16]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [32]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [32]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [32]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 16, 32]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [32]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [32]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [32]),
#  ('Flow/inception_i3d/Mixed_3b/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 192, 32]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [128]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [128]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [128]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 256, 128]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [128]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [128]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [128]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 256, 128]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [192]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [192]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [192]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 128, 192]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [32]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [32]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [32]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 256, 32]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [96]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [96]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [96]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 32, 96]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [64]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [64]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [64]),
#  ('Flow/inception_i3d/Mixed_3c/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 256, 64]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [192]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [192]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [192]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 480, 192]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [96]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [96]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [96]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 480, 96]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [208]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [208]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [208]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 96, 208]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [16]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [16]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [16]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 480, 16]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [48]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [48]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [48]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 16, 48]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [64]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4b/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 480, 64]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [160]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [160]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [160]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 160]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [112]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [112]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [112]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 112]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [224]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [224]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [224]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 112, 224]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [24]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [24]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [24]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 24]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [64]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 24, 64]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [64]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4c/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 512, 64]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [128]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [128]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [128]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 128]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [128]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [128]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [128]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 128]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [256]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [256]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [256]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 128, 256]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [24]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [24]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [24]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 24]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [64]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 24, 64]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [64]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4d/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 512, 64]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [112]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [112]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [112]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 112]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [144]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [144]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [144]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 144]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [288]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [288]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [288]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 144, 288]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [32]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [32]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [32]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 32]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [64]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 32, 64]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [64]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [64]),
#  ('Flow/inception_i3d/Mixed_4e/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 512, 64]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [256]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [256]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [256]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 528, 256]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [160]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [160]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [160]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 528, 160]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [320]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [320]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [320]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 160, 320]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [32]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [32]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [32]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 528, 32]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [128]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [128]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [128]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 32, 128]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [128]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [128]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [128]),
#  ('Flow/inception_i3d/Mixed_4f/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 528, 128]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [256]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [256]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [256]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 832, 256]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [160]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [160]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [160]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 832, 160]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [320]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [320]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [320]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 160, 320]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [32]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [32]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [32]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 832, 32]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_3x3/batch_norm/beta', [128]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_3x3/batch_norm/moving_mean',
#   [128]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_3x3/batch_norm/moving_variance',
#   [128]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_3x3/conv_3d/w',
#   [3, 3, 3, 32, 128]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [128]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [128]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [128]),
#  ('Flow/inception_i3d/Mixed_5b/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 832, 128]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [384]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [384]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [384]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 832, 384]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [192]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [192]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [192]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 832, 192]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [384]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [384]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [384]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 192, 384]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [48]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [48]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [48]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 832, 48]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [128]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [128]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [128]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 48, 128]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [128]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [128]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [128]),
#  ('Flow/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 832, 128])]

# %%
flow_vardict = {}
# make variables to load the saved weights into
for variable in flow_varlist:
    flow_vardict[variable[0]] = tf.Variable(initial_value = np.zeros(variable[1], dtype=np.float32),
                                            shape=tf.TensorShape(variable[1]),
                                            trainable=fine_tuning,
                                            name=variable[0])
    
flow_saver = tf.compat.v1.train.Saver(var_list=flow_vardict)
flow_saver.restore(sess=None, save_path=_CHECKPOINT_PATHS['flow_imagenet'])
# the warning message here is irrelevant
# Out:
# WARNING:tensorflow:Saver is deprecated, please switch to tf.train.Checkpoint or tf.keras.Model.save_weights for training checkpoints. When executing eagerly variables do not necessarily have unique names, and so the variable.name-based lookups Saver performs are error-prone.
# INFO:tensorflow:Restoring parameters from i3d/data/checkpoints/flow_imagenet/model.ckpt

# %%
rgb_varlist = tf.train.list_variables("i3d/data/checkpoints/rgb_imagenet/model.ckpt")
rgb_varlist
# Out:
# [('RGB/inception_i3d/Conv3d_1a_7x7/batch_norm/beta', [64]),
#  ('RGB/inception_i3d/Conv3d_1a_7x7/batch_norm/moving_mean', [64]),
#  ('RGB/inception_i3d/Conv3d_1a_7x7/batch_norm/moving_variance', [64]),
#  ('RGB/inception_i3d/Conv3d_1a_7x7/conv_3d/w', [7, 7, 7, 3, 64]),
#  ('RGB/inception_i3d/Conv3d_2b_1x1/batch_norm/beta', [64]),
#  ('RGB/inception_i3d/Conv3d_2b_1x1/batch_norm/moving_mean', [64]),
#  ('RGB/inception_i3d/Conv3d_2b_1x1/batch_norm/moving_variance', [64]),
#  ('RGB/inception_i3d/Conv3d_2b_1x1/conv_3d/w', [1, 1, 1, 64, 64]),
#  ('RGB/inception_i3d/Conv3d_2c_3x3/batch_norm/beta', [192]),
#  ('RGB/inception_i3d/Conv3d_2c_3x3/batch_norm/moving_mean', [192]),
#  ('RGB/inception_i3d/Conv3d_2c_3x3/batch_norm/moving_variance', [192]),
#  ('RGB/inception_i3d/Conv3d_2c_3x3/conv_3d/w', [3, 3, 3, 64, 192]),
#  ('RGB/inception_i3d/Logits/Conv3d_0c_1x1/conv_3d/b', [400]),
#  ('RGB/inception_i3d/Logits/Conv3d_0c_1x1/conv_3d/w', [1, 1, 1, 1024, 400]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [64]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [64]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [64]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 192, 64]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [96]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [96]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [96]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 192, 96]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [128]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [128]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [128]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 96, 128]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [16]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [16]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [16]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 192, 16]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [32]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [32]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [32]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 16, 32]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [32]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [32]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [32]),
#  ('RGB/inception_i3d/Mixed_3b/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 192, 32]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [128]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [128]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [128]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 256, 128]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [128]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [128]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [128]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 256, 128]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [192]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [192]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [192]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 128, 192]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [32]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [32]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [32]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 256, 32]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [96]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [96]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [96]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 32, 96]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [64]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [64]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [64]),
#  ('RGB/inception_i3d/Mixed_3c/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 256, 64]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [192]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [192]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [192]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 480, 192]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [96]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [96]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [96]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 480, 96]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [208]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [208]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [208]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 96, 208]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [16]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [16]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [16]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 480, 16]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [48]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [48]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [48]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 16, 48]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [64]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4b/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 480, 64]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [160]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [160]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [160]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 160]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [112]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [112]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [112]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 112]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [224]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [224]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [224]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 112, 224]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [24]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [24]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [24]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 24]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [64]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 24, 64]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [64]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4c/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 512, 64]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [128]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [128]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [128]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 128]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [128]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [128]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [128]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 128]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [256]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [256]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [256]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 128, 256]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [24]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [24]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [24]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 24]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [64]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 24, 64]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [64]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4d/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 512, 64]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [112]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [112]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [112]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 112]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [144]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [144]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [144]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 144]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [288]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [288]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [288]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 144, 288]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [32]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [32]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [32]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 512, 32]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [64]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 32, 64]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [64]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [64]),
#  ('RGB/inception_i3d/Mixed_4e/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 512, 64]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [256]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [256]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [256]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 528, 256]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [160]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [160]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [160]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 528, 160]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [320]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [320]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [320]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 160, 320]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [32]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [32]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [32]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 528, 32]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [128]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [128]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [128]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 32, 128]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [128]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [128]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [128]),
#  ('RGB/inception_i3d/Mixed_4f/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 528, 128]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [256]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [256]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [256]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 832, 256]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [160]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [160]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [160]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 832, 160]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [320]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [320]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [320]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 160, 320]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [32]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [32]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [32]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 832, 32]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_3x3/batch_norm/beta', [128]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_3x3/batch_norm/moving_mean',
#   [128]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_3x3/batch_norm/moving_variance',
#   [128]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_2/Conv3d_0a_3x3/conv_3d/w',
#   [3, 3, 3, 32, 128]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [128]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [128]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [128]),
#  ('RGB/inception_i3d/Mixed_5b/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 832, 128]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_0/Conv3d_0a_1x1/batch_norm/beta', [384]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_0/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [384]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_0/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [384]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_0/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 832, 384]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_1/Conv3d_0a_1x1/batch_norm/beta', [192]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_1/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [192]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_1/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [192]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_1/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 832, 192]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_1/Conv3d_0b_3x3/batch_norm/beta', [384]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_1/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [384]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_1/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [384]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_1/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 192, 384]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_2/Conv3d_0a_1x1/batch_norm/beta', [48]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_2/Conv3d_0a_1x1/batch_norm/moving_mean',
#   [48]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_2/Conv3d_0a_1x1/batch_norm/moving_variance',
#   [48]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_2/Conv3d_0a_1x1/conv_3d/w',
#   [1, 1, 1, 832, 48]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_2/Conv3d_0b_3x3/batch_norm/beta', [128]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_2/Conv3d_0b_3x3/batch_norm/moving_mean',
#   [128]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_2/Conv3d_0b_3x3/batch_norm/moving_variance',
#   [128]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_2/Conv3d_0b_3x3/conv_3d/w',
#   [3, 3, 3, 48, 128]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/batch_norm/beta', [128]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean',
#   [128]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance',
#   [128]),
#  ('RGB/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/conv_3d/w',
#   [1, 1, 1, 832, 128])]

# %%
rgb_vardict = {}
for variable in rgb_varlist:
    rgb_vardict[variable[0]] = tf.Variable(initial_value = np.zeros(variable[1], dtype=np.float32),
                                           shape=tf.TensorShape(variable[1]), 
                                           trainable=fine_tuning,
                                           name=variable[0])
rgb_saver = tf.compat.v1.train.Saver(var_list=rgb_vardict, reshape=True)
rgb_saver.restore(sess=None, save_path=_CHECKPOINT_PATHS['rgb_imagenet'])
# Out:
# WARNING:tensorflow:Saver is deprecated, please switch to tf.train.Checkpoint or tf.keras.Model.save_weights for training checkpoints. When executing eagerly variables do not necessarily have unique names, and so the variable.name-based lookups Saver performs are error-prone.
# INFO:tensorflow:Restoring parameters from i3d/data/checkpoints/rgb_imagenet/model.ckpt

# %%
# now vardict will contain all the weights
vardict = {}
vardict.update(rgb_vardict)
vardict.update(flow_vardict)
vardict
# Out:
# {'RGB/inception_i3d/Conv3d_1a_7x7/batch_norm/beta': <tf.Variable 'RGB/inception_i3d/Conv3d_1a_7x7/batch_norm/beta:0' shape=(64,) dtype=float32, numpy=
#  array([ 1.8795129 , -1.3898429 ,  1.8669838 ,  0.28919575,  0.27221254,
#          1.6464163 ,  2.087254  ,  2.117959  , -0.8038748 ,  2.4320054 ,
#          1.759102  ,  1.7645339 ,  1.465036  ,  1.3237163 ,  1.9335492 ,
#         -1.3406926 ,  1.78503   ,  2.4907627 ,  2.5260837 ,  2.207292  ,
#          0.27849734,  2.168709  , -0.8655198 ,  2.1681845 ,  2.3320682 ,
#          1.4199437 ,  1.9736975 ,  0.37483513, -1.1506578 ,  0.368478  ,
#          2.23737   , -1.1911454 , -0.07817524,  2.0920424 ,  4.7544007 ,
#         -0.08812667, -0.7181662 , -0.39324987, -0.8849777 ,  2.2050202 ,
#         -0.9242949 ,  5.6755657 ,  2.2218184 , -0.6854658 , -0.4371273 ,
#          1.0771866 ,  1.609359  ,  1.3407111 , -0.8547968 , -1.3461387 ,
#          0.29010373, -0.57551354,  2.100426  ,  2.03961   ,  2.1551318 ,
#          2.4727721 ,  2.235383  , -0.77025265,  2.3602786 ,  2.457134  ,
#          2.1921012 ,  1.53928   ,  1.657586  ,  2.0167542 ], dtype=float32)>,
#  'RGB/inception_i3d/Conv3d_1a_7x7/batch_norm/moving_mean': <tf.Variable 'RGB/inception_i3d/Conv3d_1a_7x7/batch_norm/moving_mean:0' shape=(64,) dtype=float32, numpy=
#  array([-1.0753264 , -2.059673  , -1.7907165 ,  0.1077306 , -0.36962312,
#          1.2849109 ,  0.275188  ,  0.06000243, -2.4062667 ,  1.0026997 ,
#         -1.3433053 , -2.1771479 ,  0.02019624,  0.52931976, -0.7809523 ,
#          1.0447903 ,  2.6676512 ,  2.009321  ,  1.0899189 ,  0.35923317,
#          0.24096906,  1.4955665 ,  1.6033322 ,  1.1207598 , -1.87867   ,
#         -1.2046776 ,  0.02401441, -0.20548762, -1.3146172 ,  0.28845426,
#         -1.1391786 , -0.78307575,  0.38725892,  1.6692406 , -0.23400237,
#          3.857521  ,  4.159208  , -0.95422906, -1.1738127 ,  2.1793988 ,
#         -0.01292958, -0.517364  , -1.1418784 ,  1.8063399 ,  2.3380973 ,
#          1.4711051 , -2.0105371 ,  0.82439446, -0.9415639 ,  0.64257926,
#          0.18009378,  1.4939123 , -0.10730965, -1.2845467 ,  0.841339  ,
#          1.3529575 ,  2.0306547 ,  2.2303438 , -3.4874983 ,  1.1711497 ,
#         -1.3429625 , -3.2314322 , -1.5625432 ,  1.1360916 ], dtype=float32)>,
#  'RGB/inception_i3d/Conv3d_1a_7x7/batch_norm/moving_variance': <tf.Variable 'RGB/inception_i3d/Conv3d_1a_7x7/batch_norm/moving_variance:0' shape=(64,) dtype=float32, numpy=
#  array([ 20.863905 ,  29.578363 ,  53.357376 , 187.25684  ,  98.81491  ,
#          23.581453 ,   7.1970096,  11.348876 ,  32.66017  ,  17.374075 ,
#          31.681684 ,  69.54633  ,  12.065587 ,  50.14564  ,  14.066072 ,
#          35.058956 ,  50.268124 ,  57.03501  ,  17.081425 ,  13.189356 ,
#         172.91176  ,  33.376278 ,  34.3966   ,  24.183508 ,  57.15534  ,
#          18.629572 ,   2.841299 , 171.1181   ,  21.591852 ,  60.92417  ,
#          21.15477  ,  38.29465  ,  18.729422 ,  47.81676  ,  64.55638  ,
#          65.50281  ,  75.300354 ,  51.159863 ,  32.44853  ,  68.23223  ,
#          27.428585 ,  73.897995 ,  28.782413 ,  36.176617 ,  35.482136 ,
#          50.310036 ,  69.121544 ,  12.39409  ,  21.890202 ,  28.270275 ,
#         135.84102  ,  46.273727 ,   8.731526 ,  23.278814 ,  21.29568  ,
#          26.470675 ,  62.609516 ,  50.6573   , 104.91271  ,  22.51285  ,
#          29.112743 ,  69.16186  ,  23.483906 ,  28.202099 ], dtype=float32)>,
#  'RGB/inception_i3d/Conv3d_1a_7x7/conv_3d/w': <tf.Variable 'RGB/inception_i3d/Conv3d_1a_7x7/conv_3d/w:0' shape=(7, 7, 7, 3, 64) dtype=float32, numpy=
#  array([[[[[-1.43113524e-01,  2.89910920e-02, -1.96734839e-03, ...,
#              5.84738970e-01, -2.19218582e-01, -6.37412220e-02],
#            [-1.25637278e-01,  8.11722223e-03, -2.59305201e-02, ...,
#             -2.38395650e-02,  1.21257633e-01, -3.45920883e-02],
#            [-1.40721798e-01,  1.81077216e-02,  2.82995459e-02, ...,
#             -3.61144960e-01,  8.38940814e-02,  1.91622768e-02]],
#
#           [[ 9.31346193e-02, -4.43571684e-04,  1.41852051e-02, ...,
#              5.06393790e-01, -1.15408607e-01, -1.24569058e-01],
#            [ 1.45736188e-01, -1.08611044e-02, -2.32405029e-02, ...,
#             -2.85054147e-02,  8.02800134e-02, -8.65361020e-02],
#            [ 1.41017377e-01,  4.11835359e-03,  6.28215680e-03, ...,
#             -2.85974890e-01,  6.80021942e-02, -4.29835878e-02]],
#
#           [[ 8.13764036e-02, -2.79862955e-02, -9.80952978e-02, ...,
#              3.69533807e-01,  6.01404579e-03,  9.15303305e-02],
#            [ 3.66332829e-02, -3.99244092e-02, -1.16998307e-01, ...,
#              3.41590750e-03, -1.96096841e-02,  8.82055014e-02],
#            [ 7.21027702e-02, -2.62272097e-02, -7.32129514e-02, ...,
#             -2.22033679e-01, -4.71244827e-02,  1.30045459e-01]],
#
#           ...,
#
#           [[-1.46412374e-02, -2.53867563e-02, -3.49052921e-02, ...,
#              2.30918050e-01,  1.82909966e-02, -2.46106405e-02],
#            [ 4.21691546e-03, -2.12681834e-02, -1.18708819e-01, ...,
#             -2.44775042e-03, -8.97008479e-02, -1.93983726e-02],
#            [ 3.68763357e-02,  2.38503376e-03, -6.31037876e-02, ...,
#             -1.96795523e-01, -1.00606233e-01, -9.32376739e-03]],
#
#           [[-8.09475593e-03, -2.35008001e-02, -5.08991107e-02, ...,
#              2.74112940e-01, -2.60301167e-03, -5.49707897e-02],
#            [-2.81219315e-02, -1.54289249e-02, -1.24524854e-01, ...,
#              3.05886455e-02, -5.11008315e-02, -3.99105139e-02],
#            [-6.32119272e-03,  5.88322338e-03, -7.30789825e-02, ...,
#             -2.44159639e-01, -5.42656742e-02, -6.60977289e-02]],
#
#           [[ 1.85360387e-02,  2.63535231e-02,  1.87925875e-01, ...,
#              2.05882147e-01, -2.92426705e-01, -3.97085845e-02],
#            [-1.00247795e-03,  2.62552481e-02,  1.06371969e-01, ...,
#              4.61943522e-02, -4.19449992e-02,  1.33266076e-02],
#            [ 2.69266457e-04,  5.71511947e-02,  2.01271698e-01, ...,
#             -1.85719937e-01,  1.17380783e-01,  8.91734138e-02]]],
#
#
#          [[[ 7.74534866e-02,  8.76242574e-03,  4.32061478e-02, ...,
#              3.99435461e-01, -2.05229774e-01, -9.89522636e-02],
#            [ 6.94482848e-02, -6.36266265e-03,  1.90174859e-02, ...,
#             -6.38469756e-02,  1.10038549e-01, -7.90971741e-02],
#            [ 8.55384395e-02,  5.95593965e-03,  7.32674897e-02, ...,
#             -2.93720931e-01,  1.19491637e-01, -7.94421509e-02]],
#
#           [[ 2.35607624e-01, -1.22820036e-02,  5.62839657e-02, ...,
#              3.10380757e-01, -1.14971802e-01, -8.92366916e-02],
#            [ 2.66473204e-01, -1.64104439e-02,  2.02323720e-02, ...,
#             -8.87545273e-02,  5.62265143e-02, -6.12876043e-02],
#            [ 2.93862641e-01, -1.86263444e-03,  4.48800847e-02, ...,
#             -2.33028576e-01,  9.59370136e-02, -6.88496679e-02]],
#
#           [[ 2.65864749e-02, -2.97586396e-02, -5.92506416e-02, ...,
#              1.64445356e-01,  1.66409798e-02,  6.61950037e-02],
#            [-2.77700759e-02, -3.31927426e-02, -7.25115910e-02, ...,
#             -7.29943067e-02, -5.99047355e-02,  5.20358533e-02],
#            [ 4.74217422e-02, -2.47774608e-02, -3.83767746e-02, ...,
#             -1.84966013e-01, -2.68022381e-02,  5.88008203e-02]],
#
#           ...,
#
#           [[-3.95964161e-02, -3.04889418e-02, -5.75449131e-03, ...,
#              1.11967333e-01,  1.31802291e-01,  2.62320153e-02],
#            [-4.04334208e-03, -2.36125961e-02, -7.35003278e-02, ...,
#             -4.97638844e-02, -1.00796387e-01,  3.72201838e-02],
#            [ 3.20543200e-02, -4.31887573e-03, -3.06882001e-02, ...,
#             -1.43934146e-01, -9.01069269e-02, -1.79208890e-02]],
#
#           [[-1.62020940e-02, -2.79172771e-02, -6.92391545e-02, ...,
#              2.02744275e-01,  1.17062032e-01, -3.32087614e-02],
#            [-3.31925191e-02, -2.16889288e-02, -1.29308000e-01, ...,
#              1.54889611e-04, -5.53372912e-02, -8.68905522e-03],
#            [ 4.75064066e-04, -1.54693017e-03, -8.19217712e-02, ...,
#             -1.87498793e-01, -5.73562160e-02, -1.04328334e-01]],
#
#           [[-5.19268867e-03,  2.03307513e-02,  1.11760736e-01, ...,
#              1.58853531e-01, -1.95742160e-01, -4.50059883e-02],
#            [-2.91089956e-02,  1.78322755e-02,  4.55070399e-02, ...,
#              1.16961226e-02, -4.12739180e-02,  1.52115915e-02],
#            [-1.47942929e-02,  4.65859734e-02,  1.40029147e-01, ...,
#             -1.54707655e-01,  1.17210135e-01,  3.90625447e-02]]],
#
#
#          [[[ 1.09026678e-01, -6.15689158e-03,  1.40674394e-02, ...,
#              2.45453998e-01, -1.94779947e-01, -5.78178763e-02],
#            [ 5.46521656e-02, -1.50450775e-02, -3.77623294e-03, ...,
#             -4.50544693e-02,  1.42538175e-01, -6.72799796e-02],
#            [ 1.03565253e-01, -1.12109482e-02,  4.38194759e-02, ...,
#             -2.30403170e-01,  1.94484726e-01, -7.20240399e-02]],
#
#           [[ 1.21626452e-01, -7.43695768e-03,  3.34516801e-02, ...,
#              1.90092459e-01, -1.20828569e-01, -1.96125582e-02],
#            [ 1.10244393e-01, -6.17749430e-03,  1.71082537e-03, ...,
#             -4.69890609e-02,  9.33247507e-02, -2.79054251e-02],
#            [ 1.71292663e-01, -4.98945639e-03,  1.63042247e-02, ...,
#             -1.46682337e-01,  1.80097073e-01, -2.41189543e-02]],
#
#           [[-1.09110057e-01, -7.28972675e-03, -7.62992352e-02, ...,
#              6.20340854e-02,  2.23591588e-02,  4.60968278e-02],
#            [-2.01473981e-01, -3.26862023e-03, -7.97710642e-02, ...,
#             -3.39051038e-02, -5.99027891e-03, -7.39900442e-03],
#            [-1.39579132e-01, -1.07531669e-02, -6.01284020e-02, ...,
#             -9.59541127e-02,  9.46110487e-02,  1.66875627e-02]],
#
#           ...,
#
#           [[-1.42293116e-02, -3.12923156e-02, -3.37122679e-02, ...,
#              4.54862341e-02,  2.31068864e-01,  1.30823657e-01],
#            [ 6.87915552e-03, -2.21881922e-02, -8.40222239e-02, ...,
#             -2.98895929e-02, -6.62257075e-02,  1.15629576e-01],
#            [ 2.07690578e-02, -1.73981395e-02, -6.74716011e-02, ...,
#             -8.66966993e-02, -3.99177335e-03,  3.43595333e-02]],
#
#           [[-5.73780341e-03, -4.52427790e-02, -1.27026320e-01, ...,
#              1.64615586e-01,  2.32776240e-01,  3.95940989e-03],
#            [-6.02103435e-02, -4.02320735e-02, -1.65562257e-01, ...,
#              1.03655243e-02, -3.39145809e-02,  4.28820727e-03],
#            [-1.33891469e-02, -3.18947062e-02, -1.48445874e-01, ...,
#             -1.47558972e-01, -1.01557346e-02, -9.65479985e-02]],
#
#           [[ 2.72660367e-02, -6.99670380e-03,  2.48124450e-02, ...,
#              1.36755586e-01, -5.43668494e-02, -4.82938252e-02],
#            [-5.36720641e-02, -1.54664265e-02, -2.77804006e-02, ...,
#              6.03437517e-03,  2.65315105e-03, -1.79204829e-02],
#            [-3.56344394e-02,  4.41458821e-03,  3.88259180e-02, ...,
#             -1.41276762e-01,  1.56013086e-01,  2.77533382e-02]]],
#
#
#          ...,
#
#
#          [[[ 3.28886285e-02, -7.30808312e-03,  2.81128790e-02, ...,
#              1.55970454e-01, -1.86162755e-01, -5.18510863e-02],
#            [ 5.47033327e-04,  2.81715929e-03,  1.64586920e-02, ...,
#              3.66783217e-02,  2.72747334e-02,  9.73887928e-03],
#            [ 5.42245731e-02,  7.80523894e-03,  7.23692253e-02, ...,
#             -8.78315940e-02, -1.10312540e-03,  3.12997550e-02]],
#
#           [[ 2.37684064e-02, -1.27370674e-02,  5.38762845e-02, ...,
#              1.51525736e-01, -1.58451200e-01, -7.08302110e-02],
#            [ 5.58998771e-02, -5.47052245e-04,  2.64384672e-02, ...,
#              3.02201584e-02,  1.75683238e-02, -6.36615977e-03],
#            [ 7.88073614e-02, -6.33005926e-04,  6.64851889e-02, ...,
#             -2.46773884e-02,  3.57542895e-02,  3.30929793e-02]],
#
#           [[-3.33611108e-02, -5.16996428e-04, -6.14278205e-02, ...,
#              8.49488527e-02, -1.14117265e-01,  4.18717153e-02],
#            [-7.43899569e-02,  5.71302325e-03, -6.86447248e-02, ...,
#              3.72681767e-02, -4.59326431e-02,  6.93362877e-02],
#            [-6.44010529e-02, -3.36307334e-03, -8.44950695e-03, ...,
#              1.04705440e-02,  2.02084761e-02,  1.03445463e-01]],
#
#           ...,
#
#           [[-6.22388767e-03, -1.65988076e-02,  4.36161011e-02, ...,
#              1.02642052e-01,  9.30415690e-02, -1.26735447e-02],
#            [-8.18391447e-04, -4.27138200e-03,  1.52379097e-02, ...,
#             -1.44346301e-02, -1.04524776e-01,  1.79691594e-02],
#            [ 5.71682565e-02, -5.95726445e-03,  2.72324923e-02, ...,
#             -6.13026209e-02, -2.41375752e-02, -3.99938822e-02]],
#
#           [[ 1.45405695e-01, -3.56134661e-02, -2.87208892e-02, ...,
#              2.22862259e-01,  1.31829560e-01, -8.87662098e-02],
#            [ 1.06938988e-01, -2.60914136e-02, -4.36696224e-02, ...,
#              1.00711752e-02, -1.09734960e-01, -5.35928831e-02],
#            [ 1.32339925e-01, -2.40425598e-02, -5.36721870e-02, ...,
#             -1.31256878e-01, -8.19744319e-02, -1.07353166e-01]],
#
#           [[ 1.21266894e-01, -3.48593015e-03,  1.11512057e-01, ...,
#              2.10340947e-01, -7.97856823e-02, -1.95822492e-02],
#            [ 5.73293343e-02, -7.96970166e-03,  8.26786309e-02, ...,
#             -1.79665117e-03, -8.44232589e-02,  3.36898081e-02],
#            [ 1.67572945e-02,  4.80236998e-03,  1.22302286e-01, ...,
#             -1.31943345e-01,  3.43229212e-02,  9.73874182e-02]]],
#
#
#          [[[-7.10542640e-03, -1.69439875e-02, -3.10317315e-02, ...,
#              1.58484653e-01, -9.37514752e-02, -6.09762408e-02],
#            [-4.70141433e-02,  3.30713950e-03, -4.04547118e-02, ...,
#              5.26268221e-02,  9.37522575e-02,  1.51156597e-02],
#            [-1.05124339e-02,  5.09198476e-03,  6.99631777e-03, ...,
#             -1.49017602e-01,  6.28866479e-02,  3.94270755e-02]],
#
#           [[-2.53387429e-02, -2.24607494e-02, -8.39551073e-03, ...,
#              1.37943372e-01, -8.30032602e-02, -1.08722501e-01],
#            [-1.03015704e-02, -2.02467735e-03, -3.07677779e-02, ...,
#              1.00497510e-02,  8.60099792e-02, -2.74403282e-02],
#            [ 5.89533709e-03, -3.72413383e-03,  8.71646870e-03, ...,
#             -1.34301767e-01,  1.06316157e-01,  8.86839535e-03]],
#
#           [[-6.25576749e-02, -9.70291253e-03, -1.33951053e-01, ...,
#              7.95729756e-02, -1.18392169e-01,  5.25596887e-02],
#            [-1.37255192e-01,  6.90531102e-04, -1.37244612e-01, ...,
#             -4.18011146e-03,  5.56446053e-03,  9.51162055e-02],
#            [-1.07634597e-01, -1.00740958e-02, -6.28286004e-02, ...,
#             -1.28556937e-01,  7.92132467e-02,  1.08227842e-01]],
#
#           ...,
#
#           [[ 1.33866742e-01, -2.16866955e-02, -5.02529852e-02, ...,
#              1.24929443e-01,  7.10805971e-03, -6.34827539e-02],
#            [ 1.66799456e-01, -2.44454388e-03, -8.32730308e-02, ...,
#             -5.99590428e-02, -5.00895940e-02, -3.68728377e-02],
#            [ 1.77825913e-01, -7.09644007e-03, -4.99477908e-02, ...,
#             -1.87118202e-01,  5.03180437e-02, -9.24879536e-02]],
#
#           [[ 1.34974986e-01, -3.36340778e-02, -9.25781429e-02, ...,
#              2.33697504e-01,  6.41266033e-02, -8.66887197e-02],
#            [ 1.43429726e-01, -1.64295658e-02, -1.20027646e-01, ...,
#             -5.07848114e-02, -3.28227356e-02, -6.04004785e-02],
#            [ 1.15291357e-01, -1.90839265e-02, -1.16905928e-01, ...,
#             -2.60346591e-01,  2.80782171e-02, -1.11159906e-01]],
#
#           [[ 8.55564997e-02, -1.11373793e-03,  6.62130639e-02, ...,
#              2.22147733e-01, -1.03328884e-01, -3.77581380e-02],
#            [ 6.45526052e-02,  2.49918085e-04,  2.08864175e-02, ...,
#             -6.21441156e-02, -1.96582102e-03,  1.18130036e-02],
#            [-1.77680552e-02,  5.42021822e-03,  7.14492053e-02, ...,
#             -2.50254065e-01,  1.49839953e-01,  6.59464374e-02]]],
#
#
#          [[[-9.75561328e-03, -7.27845170e-03,  1.56860918e-01, ...,
#              9.60355476e-02,  1.44576326e-01, -8.37537199e-02],
#            [-5.32888733e-02,  2.64882986e-02,  6.18771948e-02, ...,
#              1.09015353e-01,  1.95168294e-02, -1.27301598e-02],
#            [-1.96069162e-02,  3.29749100e-02,  7.96749145e-02, ...,
#             -8.70269239e-02, -1.34203002e-01, -2.78421538e-03]],
#
#           [[ 3.09516173e-02, -2.52101962e-02,  1.80689529e-01, ...,
#              7.69307315e-02,  1.43067643e-01, -1.23303495e-01],
#            [ 1.97080653e-02,  6.95774006e-03,  7.93697760e-02, ...,
#              4.54727225e-02,  1.52781205e-02, -5.42976260e-02],
#            [ 4.20686230e-02,  9.67677776e-03,  9.24328268e-02, ...,
#             -1.02988183e-01, -9.23128724e-02, -3.99883762e-02]],
#
#           [[ 3.06918174e-02, -8.15366581e-03,  4.87473644e-02, ...,
#              1.77449379e-02,  1.04786962e-01,  6.01935722e-02],
#            [-6.64593577e-02,  1.52431335e-02, -3.33717503e-02, ...,
#              1.67093927e-03, -2.88521796e-02,  9.08364356e-02],
#            [-4.85835820e-02,  1.12488978e-02,  1.27540175e-02, ...,
#             -1.28309354e-01, -7.80475959e-02,  7.41501004e-02]],
#
#           ...,
#
#           [[ 5.91684096e-02, -1.53231798e-02,  6.43884018e-02, ...,
#              1.31957769e-01,  1.21753186e-01, -5.77804148e-02],
#            [ 8.85252431e-02,  1.26128178e-02, -4.77217175e-02, ...,
#             -1.80866364e-02, -1.02882452e-01, -5.59646152e-02],
#            [ 4.35447097e-02,  1.55823175e-02, -3.25623006e-02, ...,
#             -1.38389960e-01, -1.00582547e-01, -1.32112980e-01]],
#
#           [[-6.58077970e-02, -2.70865392e-02,  1.09908283e-02, ...,
#              2.40112811e-01,  1.56651691e-01, -8.22322816e-02],
#            [-4.59452011e-02, -2.86924769e-03, -1.02965057e-01, ...,
#             -1.63856726e-02, -8.40388834e-02, -7.79438093e-02],
#            [-1.18818499e-01, -1.09942502e-03, -1.17999278e-01, ...,
#             -2.07648113e-01, -1.11004263e-01, -1.55189052e-01]],
#
#           [[-4.28861715e-02,  6.50316384e-03,  1.63920507e-01, ...,
#              2.53995121e-01, -5.15178777e-02, -1.70649681e-02],
#            [-2.22632587e-02,  1.58940703e-02,  3.66322473e-02, ...,
#             -7.52506172e-03, -1.20581642e-01,  1.77569240e-02],
#            [-1.50124848e-01,  2.07073763e-02,  6.87254369e-02, ...,
#             -1.83035612e-01, -7.23484233e-02,  1.76136028e-02]]]],
#
#
#
#         [[[[-3.02607059e-01, -1.77920552e-03, -9.67131369e-03, ...,
#              5.11206985e-01, -2.79916823e-01, -5.69565482e-02],
#            [-2.22086936e-01, -1.48803620e-02, -1.76944304e-02, ...,
#             -6.08781353e-03,  2.24520609e-01, -4.65272106e-02],
#            [-1.63003132e-01, -7.98732322e-03,  3.57079394e-02, ...,
#             -3.22623372e-01,  1.43002719e-01, -2.84113996e-02]],
#
#           [[ 6.63857311e-02, -1.88728701e-02, -1.64515097e-02, ...,
#              4.06827390e-01, -1.34020180e-01, -2.89429761e-02],
#            [ 1.41496703e-01, -2.12238859e-02, -2.86781546e-02, ...,
#             -8.55741464e-03,  1.16931371e-01, -4.30763420e-03],
#            [ 2.36816779e-01, -1.04010180e-02, -1.44215277e-03, ...,
#             -2.25782230e-01,  3.89028564e-02, -4.97642113e-03]],
#
#           [[ 6.67364970e-02, -2.96871681e-02, -1.39459983e-01, ...,
#              2.59409875e-01,  7.65228495e-02,  1.57931924e-01],
#            [ 9.81143303e-03, -3.31213698e-02, -1.26671478e-01, ...,
#              3.17995064e-02, -2.40907129e-02,  1.41006798e-01],
#            [ 1.64254427e-01, -2.26411652e-02, -8.35527256e-02, ...,
#             -1.36999324e-01, -1.45399749e-01,  1.27916589e-01]],
#
#           ...,
#
#           [[ 3.28580514e-02, -2.60845441e-02, -1.12626188e-01, ...,
#              1.50849894e-01,  2.45756879e-01,  3.23690325e-02],
#            [-7.98685942e-03, -1.41245360e-02, -1.43283948e-01, ...,
#              4.32083989e-03, -1.04996800e-01,  2.85882372e-02],
#            [ 1.43255249e-01,  6.20276807e-03, -1.02991417e-01, ...,
#             -1.48726970e-01, -2.27877468e-01, -4.33658808e-02]],
#
#           [[ 3.80835310e-02, -2.59602088e-02, -1.10129900e-01, ...,
#              2.24473521e-01,  2.80824184e-01, -1.55324396e-02],
#            [-4.71198373e-02, -1.03830323e-02, -1.37995139e-01, ...,
#              3.21217850e-02, -5.49339503e-02,  4.89569921e-03],
#            [ 7.37525970e-02,  6.72182394e-03, -1.09350771e-01, ...,
#             -2.19965696e-01, -1.63105994e-01, -1.14073582e-01]],
#
#           [[ 7.72952288e-02,  1.46436691e-02,  1.26478463e-01, ...,
#              2.33974218e-01, -5.32783642e-02, -3.33794244e-02],
#            [-2.24955752e-03,  1.70357842e-02,  8.32842588e-02, ...,
#              7.01864660e-02, -7.43141621e-02,  1.95315238e-02],
#            [ 9.41186994e-02,  4.34390716e-02,  1.39886409e-01, ...,
#             -1.71452165e-01,  2.79617799e-03,  1.21292127e-02]]],
#
#
#          [[[ 6.23369515e-02, -1.60816927e-02,  4.74062711e-02, ...,
#              2.76535690e-01, -3.05201381e-01, -1.02160133e-01],
#            [ 9.33042020e-02, -1.67189445e-02,  3.89717221e-02, ...,
#             -5.38504086e-02,  2.18963340e-01, -1.11158885e-01],
#            [ 2.00792879e-01, -9.88954678e-03,  9.85098258e-02, ...,
#             -2.36883670e-01,  2.00546250e-01, -1.36550590e-01]],
#
#           [[ 2.33704418e-01, -3.20675224e-02,  5.23694083e-02, ...,
#              1.68466449e-01, -1.77397296e-01,  1.52996450e-03],
#            [ 2.71046400e-01, -2.03677006e-02,  4.55169715e-02, ...,
#             -6.88903406e-02,  8.68330076e-02,  1.41075451e-03],
#            [ 4.20417458e-01, -1.18423514e-02,  7.49761537e-02, ...,
#             -1.44168794e-01,  7.53068700e-02, -3.01148016e-02]],
#
#           [[-5.23528121e-02, -3.70825529e-02, -7.06552938e-02, ...,
#              3.06017082e-02,  5.74071482e-02,  1.13575339e-01],
#            [-1.29265442e-01, -2.36774310e-02, -4.03495468e-02, ...,
#             -2.66162269e-02, -6.54249340e-02,  7.23657459e-02],
#            [ 8.27517807e-02, -2.13809535e-02, -5.21211326e-03, ...,
#             -5.22834063e-02, -1.15553260e-01,  4.90304977e-02]],
#
#           ...,
#
#           [[-2.42320984e-03, -3.66192348e-02, -4.64136004e-02, ...,
#              1.26573676e-02,  3.67210537e-01,  7.94027150e-02],
#            [-3.89668867e-02, -1.60399247e-02, -4.31608967e-02, ...,
#             -3.09129003e-02, -1.01247422e-01,  7.24964067e-02],
#            [ 1.27825797e-01, -2.79171043e-03, -2.17566714e-02, ...,
#             -5.54830283e-02, -1.95942059e-01, -4.77986597e-02]],
#
#           [[ 1.82305207e-03, -3.17408442e-02, -1.08561277e-01, ...,
#              1.18914023e-01,  4.39890057e-01,  1.76717329e-03],
#            [-9.01159570e-02, -1.38741182e-02, -1.04304187e-01, ...,
#             -8.77132546e-03, -1.79981068e-02,  2.62517259e-02],
#            [ 5.51539734e-02,  1.76952759e-04, -8.62579495e-02, ...,
#             -1.47974029e-01, -1.23428695e-01, -1.41059384e-01]],
#
#           [[ 3.88160124e-02,  1.33010317e-02,  2.83988230e-02, ...,
#              1.55918255e-01,  1.14763126e-01, -4.12084050e-02],
#            [-5.04027568e-02,  1.50505006e-02,  1.50305573e-02, ...,
#              1.71540808e-02, -9.47359018e-03,  1.85492560e-02],
#            [ 6.74818829e-02,  3.76183949e-02,  6.66369125e-02, ...,
#             -1.38284564e-01,  6.87481686e-02, -1.69627946e-02]]],
#
#
#          [[[ 8.85680020e-02, -2.68128607e-02,  2.52507590e-02, ...,
#              8.41359273e-02, -3.11084390e-01, -6.54488057e-02],
#            [ 6.37093931e-02, -1.51594151e-02,  1.67293977e-02, ...,
#             -4.18413132e-02,  2.91558504e-01, -1.09303504e-01],
#            [ 2.11371988e-01, -2.02599466e-02,  7.58637562e-02, ...,
#             -1.59572616e-01,  3.49702299e-01, -1.25937104e-01]],
#
#           [[ 3.24912481e-02, -2.70418618e-02,  2.57289503e-02, ...,
#              8.15820787e-03, -2.13991135e-01,  5.56874089e-02],
#            [ 2.04421524e-02, -3.05504887e-03,  2.29955111e-02, ...,
#             -3.99090052e-02,  1.49874076e-01,  1.39393033e-02],
#            [ 2.13944077e-01, -1.21419113e-02,  4.46086489e-02, ...,
#             -4.73765433e-02,  2.17376471e-01,  7.50428252e-03]],
#
#           [[-2.13048205e-01, -1.97546780e-02, -9.45923924e-02, ...,
#             -9.63364467e-02,  2.71952935e-02,  9.21464190e-02],
#            [-3.23278040e-01,  9.12887137e-03, -5.18928580e-02, ...,
#              1.24011710e-02,  7.60587212e-03,  1.92964030e-03],
#            [-1.14667870e-01, -8.62937700e-03, -2.89279986e-02, ...,
#              6.12064824e-02,  5.33377007e-02,  1.12309931e-02]],
#
#           ...,
#
#           [[ 4.32874449e-03, -3.35444063e-02, -5.06517962e-02, ...,
#             -7.21557736e-02,  4.09596503e-01,  1.99930608e-01],
#            [-3.50283831e-02, -6.11071521e-03, -2.33204160e-02, ...,
#             -1.23567935e-02, -8.01407248e-02,  1.57608390e-01],
#            [ 1.17188387e-01, -1.10762483e-02, -3.08645125e-02, ...,
#              2.22694203e-02, -1.02767609e-01,  3.66932824e-02]],
#
#           [[-2.48544998e-02, -4.12212573e-02, -1.53286770e-01, ...,
#              6.41559660e-02,  5.19086361e-01,  2.41464283e-02],
#            [-1.46272764e-01, -2.21631397e-02, -1.20353617e-01, ...,
#             -3.37201497e-03,  2.79052882e-04,  1.93866007e-02],
#            [ 1.57331023e-02, -2.36652996e-02, -1.35746658e-01, ...,
#             -9.29408595e-02, -5.99672124e-02, -1.31648317e-01]],
#
#           [[ 4.01621461e-02, -1.10416277e-03, -7.84563795e-02, ...,
#              1.16917364e-01,  2.46065617e-01, -4.01088856e-02],
#            [-1.01524204e-01, -3.61351413e-03, -7.55877793e-02, ...,
#              1.39368454e-03,  4.72072288e-02, -1.32732298e-02],
#            [ 2.58860644e-02,  7.08445720e-03, -5.30200526e-02, ...,
#             -1.20154567e-01,  1.31890208e-01, -2.97062728e-03]]],
#
#
#          ...,
#
#
#          [[[ 4.58940677e-02, -1.66685171e-02,  6.40878156e-02, ...,
#              4.73818555e-02, -3.82773221e-01, -4.50818464e-02],
#            [ 7.06963427e-03,  1.36687690e-02,  7.30699971e-02, ...,
#              5.18704876e-02,  2.11049780e-01, -1.55234672e-02],
#            [ 1.46683410e-01,  6.36852346e-03,  1.35757133e-01, ...,
#             -1.35673331e-02,  2.60912061e-01, -2.55347714e-02]],
#
#           [[-1.50149176e-02, -2.62182746e-02,  5.05190305e-02, ...,
#              4.28746641e-02, -3.28847647e-01, -3.15049626e-02],
#            [-1.06507251e-02,  6.09264290e-03,  6.04146272e-02, ...,
#              5.84012754e-02,  1.37270838e-01,  1.62462506e-03],
#            [ 1.17156833e-01, -6.26818463e-03,  1.07803002e-01, ...,
#              8.49093869e-02,  2.12037623e-01,  1.63196214e-02]],
#
#           [[-6.78948164e-02, -2.01332271e-02, -8.53122249e-02, ...,
#              7.33910268e-03, -2.17367366e-01,  8.41610655e-02],
#            [-1.51913509e-01,  5.97939221e-03, -3.40348557e-02, ...,
#              1.02174908e-01,  2.31517963e-02,  7.66267553e-02],
#            [-2.48581939e-03, -1.43326214e-02,  2.76136324e-02, ...,
#              1.72844633e-01,  1.15484409e-01,  8.24764669e-02]],
#
#           ...,
#
#           [[-1.21452160e-01, -3.08129005e-02, -5.04247053e-03, ...,
#              5.06591126e-02,  8.94379169e-02,  5.13114175e-03],
#            [-1.84110388e-01, -5.61991800e-03,  5.12347519e-02, ...,
#             -8.81947204e-03, -1.24313422e-01,  1.90028008e-02],
#            [ 1.77314039e-02, -1.91248320e-02,  4.33444194e-02, ...,
#              2.55129039e-02, -6.11307658e-02, -7.84320608e-02]],
#
#           [[ 1.20846078e-01, -3.15823480e-02, -6.77018762e-02, ...,
#              1.94451675e-01,  2.47881144e-01, -1.57764912e-01],
#            [ 1.42897330e-02, -1.33034755e-02, -2.61237426e-03, ...,
#             -1.20494021e-02, -7.81178549e-02, -1.23239428e-01],
#            [ 1.68159649e-01, -2.35280879e-02, -4.09548618e-02, ...,
#             -9.51051638e-02, -7.82061443e-02, -2.12772295e-01]],
#
#           [[ 1.34298265e-01,  8.16919096e-03,  2.65236851e-02, ...,
#              2.61079401e-01,  2.59260852e-02, -2.94634439e-02],
#            [ 2.07809675e-02,  4.86207334e-03,  6.03429228e-02, ...,
#             -1.28886215e-02, -9.01507959e-02,  3.01491059e-02],
#            [ 9.60659459e-02,  5.67572424e-03,  5.90449795e-02, ...,
#             -1.26117453e-01,  1.04821958e-02,  6.68307319e-02]]],
#
#
#          [[[-8.91168788e-03, -3.29152644e-02,  3.21279815e-03, ...,
#              8.17001313e-02, -3.68334442e-01, -5.45822792e-02],
#            [-6.79536685e-02,  3.21617420e-03,  2.59341300e-02, ...,
#              5.90339452e-02,  2.41757646e-01, -1.07466299e-02],
#            [ 3.12545970e-02, -7.09388219e-03,  7.67663866e-02, ...,
#             -1.01975359e-01,  3.20773035e-01, -2.51701232e-02]],
#
#           [[-5.90568036e-02, -4.10507470e-02, -2.01446209e-02, ...,
#              7.64247626e-02, -3.10992777e-01, -9.67111290e-02],
#            [-8.08605477e-02, -6.08698744e-03,  4.35529836e-03, ...,
#              3.46082300e-02,  2.05709323e-01, -4.95925657e-02],
#            [ 2.19617113e-02, -1.85775813e-02,  4.93390635e-02, ...,
#             -5.01242727e-02,  3.16682190e-01, -4.57721539e-02]],
#
#           [[-7.28633553e-02, -3.38383429e-02, -1.59532234e-01, ...,
#              1.43972114e-02, -2.70284623e-01,  8.68635029e-02],
#            [-2.05047086e-01, -9.61920246e-03, -1.01817176e-01, ...,
#              1.50769642e-02,  1.01545900e-01,  9.38241407e-02],
#            [-5.73457666e-02, -2.98022497e-02, -2.33145021e-02, ...,
#             -3.32205221e-02,  2.39214718e-01,  7.44683072e-02]],
#
#           ...,
#
#           [[ 1.34021729e-01, -3.27897817e-02, -1.14901341e-01, ...,
#              7.89170936e-02, -6.07589819e-02, -1.91447455e-02],
#            [ 9.72756371e-02, -7.17707630e-03, -6.67145550e-02, ...,
#             -1.05493061e-01, -4.44878191e-02, -1.21193770e-02],
#            [ 2.42284223e-01, -2.16751881e-02, -4.78593707e-02, ...,
#             -1.73733220e-01,  7.77155608e-02, -1.02180928e-01]],
#
#           [[ 1.78502008e-01, -2.79834252e-02, -1.48525387e-01, ...,
#              2.51273185e-01,  9.67268944e-02, -8.64709169e-02],
#            [ 1.22820243e-01, -8.60340055e-03, -9.76192802e-02, ...,
#             -8.28547254e-02,  3.12325847e-03, -6.19000494e-02],
#            [ 2.14063779e-01, -2.19237991e-02, -1.17493384e-01, ...,
#             -2.53983021e-01,  7.36188889e-02, -1.39879003e-01]],
#
#           [[ 6.61016479e-02,  8.77724867e-03, -4.39212956e-02, ...,
#              3.35787863e-01, -7.12333918e-02,  1.68169327e-02],
#            [ 1.70083286e-03,  5.82060777e-03, -2.35904492e-02, ...,
#             -5.60234785e-02, -2.47748801e-03,  7.33953118e-02],
#            [ 1.71878524e-02,  2.16712506e-04, -7.60689052e-03, ...,
#             -2.43385553e-01,  1.64893702e-01,  1.08503215e-01]]],
#
#
#          [[[ 2.94212941e-02, -2.72077471e-02,  2.24583119e-01, ...,
#              5.03607988e-02, -1.84092328e-01, -7.14242980e-02],
#            [-4.70709987e-02,  1.87862515e-02,  1.75745323e-01, ...,
#              8.78332332e-02,  1.26133308e-01, -4.03196029e-02],
#            [ 3.32558863e-02,  1.46795576e-02,  1.85245857e-01, ...,
#             -1.01316161e-01,  1.01339370e-01, -7.12756738e-02]],
#
#           [[ 5.12907282e-02, -4.34578136e-02,  2.13081867e-01, ...,
#              5.60453236e-02, -1.31691515e-01, -1.07534066e-01],
#            [-6.02473458e-03, -1.62241701e-03,  1.67512164e-01, ...,
#              4.34380062e-02,  1.20230623e-01, -7.75964782e-02],
#            [ 8.78677070e-02, -7.12100975e-03,  1.75824732e-01, ...,
#             -8.28801543e-02,  1.27094224e-01, -1.02233671e-01]],
#
#           [[ 8.33838284e-02, -3.09064537e-02,  5.98672405e-02, ...,
#             -7.44669884e-03, -8.31543058e-02,  1.00902647e-01],
#            [-7.82451481e-02,  7.54307606e-04,  4.04127538e-02, ...,
#             -1.27085829e-02,  8.20086524e-02,  8.43492746e-02],
#            [ 3.91399451e-02, -1.07528688e-02,  8.59215707e-02, ...,
#             -1.09259501e-01,  1.26336634e-01,  2.96671726e-02]],
#
#           ...,
#
#           [[ 1.35241240e-01, -2.79751085e-02, -3.34481429e-03, ...,
#              1.35332346e-01, -1.61009617e-02, -1.64929405e-02],
#            [ 9.70053896e-02,  1.61404128e-03, -3.95025611e-02, ...,
#             -8.20440724e-02, -9.24686417e-02, -4.67134602e-02],
#            [ 1.60312027e-01, -3.50003992e-03, -4.01075147e-02, ...,
#             -1.85398266e-01, -3.12533602e-02, -1.53360516e-01]],
#
#           [[-5.04358150e-02, -2.59018503e-02, -6.14974536e-02, ...,
#              3.08789462e-01,  9.31749418e-02, -4.57311980e-02],
#            [-9.13046449e-02, -3.88889434e-03, -1.01894677e-01, ...,
#             -5.61357811e-02, -6.40924424e-02, -5.23028448e-02],
#            [-7.19857961e-02, -1.14889210e-02, -1.39681563e-01, ...,
#             -2.48354539e-01, -4.68594357e-02, -1.56847060e-01]],
#
#           [[-1.21419944e-01,  7.67815299e-03,  2.48724110e-02, ...,
#              4.11031455e-01, -1.04451887e-01,  3.17025781e-02],
#            [-1.37935385e-01,  8.92163813e-03, -4.15987149e-02, ...,
#             -6.86988328e-03, -1.34130508e-01,  6.58205375e-02],
#            [-2.05656022e-01,  3.99144413e-03, -4.01385725e-02, ...,
#             -2.16706425e-01, -4.05311063e-02,  4.99173477e-02]]]],
#
#
#
#         [[[[-2.65804809e-02, -2.02043988e-02,  1.05020881e-01, ...,
#              3.58719826e-01, -4.40565914e-01, -1.47283390e-01],
#            [ 7.22139468e-03, -2.56679449e-02,  5.80312982e-02, ...,
#             -6.82172775e-02,  1.45865008e-01, -1.17767915e-01],
#            [ 6.03112690e-02, -3.37683745e-02,  9.05267224e-02, ...,
#             -2.27677345e-01,  5.52494712e-02, -1.31143600e-01]],
#
#           [[ 3.22406381e-01, -4.03348580e-02,  1.50240421e-01, ...,
#              1.81230783e-01, -2.03618467e-01,  3.67222130e-02],
#            [ 3.42063189e-01, -2.74778884e-02,  9.01915878e-02, ...,
#             -8.99300873e-02,  6.02384619e-02,  8.75762776e-02],
#            [ 4.03014511e-01, -3.06501351e-02,  8.37796852e-02, ...,
#             -1.06585175e-01, -2.94298641e-02,  8.95163938e-02]],
#
#           [[ 1.37704715e-01, -2.55971625e-02,  6.52232617e-02, ...,
#             -4.32791933e-03,  1.37099445e-01,  1.29979849e-01],
#            [ 1.08219376e-02, -7.93322083e-03,  4.59259301e-02, ...,
#             -2.82224901e-02, -4.24279012e-02,  1.62674978e-01],
#            [ 1.22934006e-01, -1.24952542e-02,  4.48293723e-02, ...,
#              3.92936952e-02, -2.09419921e-01,  1.97353214e-01]],
#
#           ...,
#
#           [[ 1.71665549e-01, -3.21701057e-02, -1.36724234e-01, ...,
#             -2.65153926e-02,  3.77006948e-01,  1.44608933e-02],
#            [ 1.13161847e-01, -3.57052987e-03, -1.69339195e-01, ...,
#              3.33267041e-02, -1.26367360e-01,  5.78844957e-02],
#            [ 1.63114533e-01,  1.36634300e-03, -1.46343321e-01, ...,
#              1.17919400e-01, -3.12565207e-01, -6.37151022e-03]],
#
#           [[ 7.89011866e-02, -5.58890291e-02, -2.94055134e-01, ...,
#              4.33187112e-02,  4.02903855e-01,  2.59471759e-02],
#            [-3.77106876e-03, -3.20257433e-02, -3.08103502e-01, ...,
#              3.41640487e-02, -7.67286792e-02,  9.79386568e-02],
#            [ 7.85788521e-03, -2.94824932e-02, -2.72741169e-01, ...,
#              3.62233026e-03, -2.54226744e-01, -6.18549436e-02]],
#
#           [[ 3.00091901e-03, -1.70658231e-02, -1.82971343e-01, ...,
#              1.02717288e-01,  9.23584104e-02, -1.89699724e-01],
#            [-4.70039286e-02, -1.40626561e-02, -1.94763213e-01, ...,
#              7.09597394e-02, -1.58130750e-03, -1.03325702e-01],
#            [-5.75811304e-02, -4.17725835e-03, -1.12053856e-01, ...,
#              1.75259020e-02,  9.73284896e-03, -1.66427985e-01]]],
#
#
#          [[[ 3.31450701e-01, -4.28509153e-02,  1.07788727e-01, ...,
#              1.36930019e-01, -4.55646008e-01, -7.96488896e-02],
#            [ 3.14236611e-01, -2.51019020e-02,  4.56609391e-02, ...,
#             -5.92014007e-02,  1.59072429e-01, -4.78198528e-02],
#            [ 4.05227959e-01, -3.52317691e-02,  8.41545016e-02, ...,
#             -4.48847152e-02,  1.48431450e-01, -1.02372050e-01]],
#
#           [[ 2.07132891e-01, -4.54404540e-02,  1.92865804e-01, ...,
#             -2.89873071e-02, -2.51666695e-01,  1.36305839e-01],
#            [ 1.89644143e-01, -4.50430624e-03,  1.20934166e-01, ...,
#             -7.34360367e-02,  2.95431409e-02,  1.85200199e-01],
#            [ 2.91713238e-01, -1.21593848e-02,  1.15788735e-01, ...,
#              9.51432288e-02,  2.31633000e-02,  1.58497140e-01]],
#
#           [[-2.59617597e-01, -8.30135308e-03,  1.71068415e-01, ...,
#             -2.01506883e-01,  1.14871979e-01, -8.41749553e-03],
#            [-3.91962826e-01,  4.20195870e-02,  1.47047207e-01, ...,
#             -4.73757274e-03, -8.83967951e-02,  1.86386723e-02],
#            [-2.48228133e-01,  2.78713591e-02,  1.41675323e-01, ...,
#              2.55040944e-01, -1.69651881e-01,  4.95691933e-02]],
#
#           ...,
#
#           [[ 7.85910699e-04, -2.63220575e-02,  8.45474377e-02, ...,
#             -1.78805202e-01,  4.48225349e-01,  1.21694632e-01],
#            [-1.60728637e-02,  2.57953517e-02,  6.94986507e-02, ...,
#              2.44637970e-02, -1.87217027e-01,  1.73062816e-01],
#            [ 2.49585379e-02,  2.18010433e-02,  7.01618195e-02, ...,
#              2.84623593e-01, -3.29672903e-01,  5.85746281e-02]],
#
#           [[-7.98082873e-02, -6.57194033e-02, -1.69787690e-01, ...,
#             -9.87084061e-02,  5.00223041e-01,  1.50179848e-01],
#            [-1.33101568e-01, -2.76664738e-02, -1.66937739e-01, ...,
#             -1.15590496e-02, -1.19617864e-01,  2.31308013e-01],
#            [-1.21069096e-01, -3.02189030e-02, -1.46898553e-01, ...,
#              1.13327719e-01, -2.78561652e-01,  2.46231724e-02]],
#
#           [[-5.65525517e-02, -2.78563891e-02, -2.27562144e-01, ...,
#             -8.06320272e-03,  2.34089628e-01, -1.76253825e-01],
#            [-9.43033248e-02, -1.79980770e-02, -2.24234521e-01, ...,
#              8.12062249e-03,  1.74251236e-02, -8.42920467e-02],
#            [-8.99528489e-02, -1.46638062e-02, -1.50518641e-01, ...,
#              7.85809532e-02,  4.52971607e-02, -1.75622493e-01]]],
#
#
#          [[[ 1.34797782e-01, -6.12070486e-02,  2.72672456e-02, ...,
#             -1.13021843e-01, -4.57379103e-01,  1.24754226e-02],
#            [ 6.76243827e-02, -2.21946500e-02, -5.35860993e-02, ...,
#             -6.58696443e-02,  2.68966705e-01,  8.00746400e-03],
#            [ 1.83249623e-01, -4.74999025e-02, -1.02603445e-02, ...,
#              4.43805195e-02,  3.47784549e-01, -2.61397082e-02]],
#
#           [[-2.15198353e-01, -3.24238911e-02,  1.27321899e-01, ...,
#             -2.58252054e-01, -2.99389035e-01,  1.52105868e-01],
#            [-2.62672395e-01,  3.15919705e-02,  3.36550660e-02, ...,
#             -7.26183429e-02,  1.15052953e-01,  1.61166966e-01],
#            [-1.43906385e-01,  3.81467701e-03,  3.01396828e-02, ...,
#              1.95169747e-01,  2.04202354e-01,  1.73732966e-01]],
#
#           [[-3.80576104e-01,  3.63400206e-02,  1.60204813e-01, ...,
#             -4.24569160e-01,  3.80138382e-02, -1.76547527e-01],
#            [-4.94465381e-01,  1.15846939e-01,  1.17910191e-01, ...,
#             -2.24402566e-02, -2.99186930e-02, -1.98017746e-01],
#            [-3.86179566e-01,  7.89023563e-02,  1.06856562e-01, ...,
#              3.47263157e-01,  5.17617445e-03, -1.14817508e-01]],
#
#           ...,
#
#           [[ 4.62125763e-02,  4.24937671e-03,  2.42086232e-01, ...,
#             -3.89355063e-01,  4.32938069e-01,  3.16688985e-01],
#            [ 8.16825479e-02,  7.53117353e-02,  2.25210324e-01, ...,
#             -5.68992570e-02, -2.04307958e-01,  3.26998442e-01],
#            [ 1.08628646e-01,  5.07734567e-02,  1.92832500e-01, ...,
#              2.95923918e-01, -2.55363107e-01,  2.18492553e-01]],
#
#           [[-1.33593962e-01, -6.44212589e-02, -3.07571068e-02, ...,
#             -2.38530412e-01,  5.14454782e-01,  2.29956776e-01],
#            [-1.89401478e-01, -1.50898965e-02, -2.17111371e-02, ...,
#             -7.36756623e-02, -1.51981905e-01,  2.71836460e-01],
#            [-1.46350026e-01, -3.55866849e-02, -3.96049730e-02, ...,
#              1.27876535e-01, -2.47256473e-01,  8.51343721e-02]],
#
#           [[ 4.78925323e-03, -3.92406322e-02, -1.79437220e-01, ...,
#             -1.00537628e-01,  3.15606207e-01, -1.93070605e-01],
#            [-6.76086918e-02, -2.67284904e-02, -1.80681929e-01, ...,
#             -5.30960858e-02,  3.65097933e-02, -1.50718287e-01],
#            [-3.27543616e-02, -3.83767560e-02, -1.39626831e-01, ...,
#              7.77762309e-02,  8.54606181e-02, -1.89870700e-01]]],
#
#
#          ...,
#
#
#          [[[ 8.70974585e-02, -6.11644164e-02, -6.02791421e-02, ...,
#             -1.15637332e-01, -5.27708769e-01,  4.58076410e-02],
#            [ 2.00261977e-02, -3.21862590e-03, -1.16008863e-01, ...,
#              3.14814635e-02,  2.64278024e-01,  1.31250352e-01],
#            [ 8.57848451e-02, -2.81514656e-02, -4.77667898e-02, ...,
#              1.81606516e-01,  3.79400551e-01,  1.31394088e-01]],
#
#           [[-2.54533347e-02, -6.57286867e-02, -7.81200528e-02, ...,
#             -2.15765506e-01, -4.71034914e-01,  1.56701170e-02],
#            [-1.36501482e-02,  4.10190504e-03, -1.62486538e-01, ...,
#             -9.21779126e-03,  1.40061587e-01,  1.04708880e-01],
#            [ 4.94531775e-03, -2.39436366e-02, -1.07855685e-01, ...,
#              2.77958870e-01,  2.80380279e-01,  1.64036244e-01]],
#
#           [[ 8.37198347e-02, -2.00533047e-02, -8.46534520e-02, ...,
#             -3.36404562e-01, -2.94753164e-01, -1.16590396e-01],
#            [ 4.82960604e-02,  5.17870411e-02, -1.37234211e-01, ...,
#             -6.90065883e-03,  1.49860755e-02, -4.19956446e-02],
#            [ 8.71738568e-02,  1.70720071e-02, -7.35340416e-02, ...,
#              3.68451774e-01,  1.52199268e-01,  3.95894721e-02]],
#
#           ...,
#
#           [[-4.49834168e-01, -3.95920202e-02,  2.50172764e-01, ...,
#             -1.94868445e-01,  3.15293670e-02,  1.40249178e-01],
#            [-4.31999296e-01,  2.50899438e-02,  2.40144357e-01, ...,
#             -5.32730184e-02, -2.05724493e-01,  2.08467081e-01],
#            [-2.75266290e-01, -7.97101646e-04,  2.24646404e-01, ...,
#              2.75016963e-01, -1.09968521e-01,  1.23476312e-01]],
#
#           [[-1.18103743e-01, -6.27322346e-02,  1.07947089e-01, ...,
#              2.14914959e-02,  1.83010340e-01, -1.14598423e-01],
#            [-1.49153307e-01, -1.51571240e-02,  1.31172270e-01, ...,
#             -2.29924694e-02, -1.68760821e-01, -4.56663221e-02],
#            [-1.22564677e-02, -3.92118506e-02,  1.00184165e-01, ...,
#              1.59827247e-01, -1.43403515e-01, -1.63766965e-01]],
#
#           [[ 1.35880619e-01, -1.29942643e-02,  2.02941410e-02, ...,
#              1.55798748e-01,  4.81291711e-02, -2.72475839e-01],
#            [ 1.03840791e-01, -1.57950877e-03,  3.63337249e-02, ...,
#             -2.39052773e-02, -4.04894426e-02, -2.11672917e-01],
#            [ 1.75771892e-01, -1.90560240e-02,  6.31831661e-02, ...,
#              8.71729776e-02,  6.62354901e-02, -2.20929444e-01]]],
#
#
#          [[[ 7.85147655e-04, -7.55201876e-02, -1.06655352e-01, ...,
#             -3.35504450e-02, -5.34364641e-01,  1.13035114e-02],
#            [-7.79910833e-02, -1.87039636e-02, -1.26220122e-01, ...,
#              4.12199311e-02,  3.21330458e-01,  9.90353152e-02],
#            [-5.05905934e-02, -4.30965535e-02, -7.15382323e-02, ...,
#              6.81663454e-02,  4.80040878e-01,  9.21131819e-02]],
#
#           [[-1.12209506e-01, -8.43655020e-02, -1.78737998e-01, ...,
#             -1.21230245e-01, -4.94040012e-01, -5.42839877e-02],
#            [-1.37854800e-01, -2.08957959e-02, -2.29882106e-01, ...,
#             -2.57687848e-02,  2.24932402e-01,  4.24619131e-02],
#            [-1.23100042e-01, -4.59187701e-02, -1.75108030e-01, ...,
#              1.19003974e-01,  4.17829186e-01,  8.03726688e-02]],
#
#           [[-1.56592265e-01, -6.05912432e-02, -2.70027965e-01, ...,
#             -2.49657676e-01, -4.11181480e-01, -7.11714327e-02],
#            [-2.69465417e-01, -1.21307920e-03, -3.00432175e-01, ...,
#             -7.46116415e-02,  9.91613939e-02,  8.12523067e-03],
#            [-1.88458040e-01, -3.23617756e-02, -2.14779869e-01, ...,
#              1.42850444e-01,  3.01639587e-01,  4.67171967e-02]],
#
#           ...,
#
#           [[-1.41471341e-01, -7.39173740e-02,  3.85591649e-02, ...,
#             -9.63882059e-02, -1.53411061e-01,  2.29476690e-02],
#            [-1.17194533e-01, -1.85658056e-02,  2.76283696e-02, ...,
#             -1.41666830e-01, -7.56711140e-02,  7.05459863e-02],
#            [ 1.84512250e-02, -4.15846705e-02,  4.78672497e-02, ...,
#              4.76837680e-02,  1.01320818e-01, -1.64754279e-02]],
#
#           [[ 1.78038001e-01, -6.69107661e-02, -3.08672357e-02, ...,
#              1.24397323e-01,  1.60477478e-02, -9.68087614e-02],
#            [ 1.88840494e-01, -2.63587795e-02, -1.65783633e-02, ...,
#             -1.05838433e-01, -1.37220798e-02, -5.31268604e-02],
#            [ 2.86612153e-01, -5.01438938e-02, -2.13302635e-02, ...,
#             -4.64516394e-02,  9.97963920e-02, -1.68492123e-01]],
#
#           [[ 1.43314391e-01, -1.26911243e-02, -5.54791391e-02, ...,
#              2.63507545e-01, -6.64034933e-02, -1.44842386e-01],
#            [ 1.57253906e-01, -5.98860625e-03, -4.88221087e-02, ...,
#             -8.67459476e-02,  1.07869811e-01, -1.02245294e-01],
#            [ 1.95271179e-01, -2.76458934e-02,  1.80046016e-04, ...,
#             -8.37205648e-02,  2.97445714e-01, -1.17716968e-01]]],
#
#
#          [[[ 4.86251563e-02, -4.93047945e-02,  1.97991326e-01, ...,
#              4.52675931e-02, -3.37749749e-01, -2.84012109e-02],
#            [-3.90136652e-02,  9.01521090e-03,  1.62700966e-01, ...,
#              1.11910224e-01,  2.39907771e-01,  3.28865163e-02],
#            [-3.06720752e-02, -7.07829231e-03,  1.64098024e-01, ...,
#              5.31911179e-02,  2.89590567e-01, -1.33839333e-02]],
#
#           [[ 5.22188880e-02, -6.33133873e-02,  1.18635558e-01, ...,
#             -2.58709919e-02, -2.76355386e-01, -6.30076975e-02],
#            [-6.71149883e-03, -2.08915514e-03,  5.52476346e-02, ...,
#              2.15953924e-02,  2.07036182e-01, -1.37878305e-04],
#            [ 6.57050079e-03, -1.92957092e-02,  6.54644892e-02, ...,
#              5.93966730e-02,  2.93471962e-01, -2.45697703e-02]],
#
#           [[ 8.51620957e-02, -3.93848605e-02, -6.88021481e-02, ...,
#             -1.38108552e-01, -1.81063190e-01,  6.05829898e-03],
#            [-6.78348839e-02,  1.61062833e-02, -1.20503403e-01, ...,
#             -5.68145923e-02,  1.66143179e-01,  4.73498441e-02],
#            [ 8.19931272e-04, -6.13701763e-03, -7.19125643e-02, ...,
#              4.29944173e-02,  2.78026849e-01,  9.65369120e-03]],
#
#           ...,
#
#           [[ 1.83204249e-01, -6.11520559e-02,  3.61635275e-02, ...,
#              3.14602330e-02, -3.15736495e-02, -2.87771355e-02],
#            [ 1.98524997e-01, -1.39872404e-02, -1.97603498e-02, ...,
#             -1.36985987e-01,  1.77126005e-02, -3.31799686e-02],
#            [ 2.61680156e-01, -2.78289076e-02, -1.88787859e-02, ...,
#             -4.87354249e-02,  1.36611015e-01, -1.67837471e-01]],
#
#           [[ 1.63822263e-01, -5.81121407e-02, -4.15855013e-02, ...,
#              2.34822541e-01,  9.01979208e-02, -3.41712981e-02],
#            [ 1.81127235e-01, -2.58249491e-02, -8.53054449e-02, ...,
#             -1.12634927e-01,  6.04994223e-02, -3.46498489e-02],
#            [ 2.03871399e-01, -4.32250947e-02, -1.06223077e-01, ...,
#             -1.37029156e-01,  1.24750450e-01, -1.97815478e-01]],
#
#           [[-9.88916308e-02, -1.09070987e-02, -3.98427024e-02, ...,
#              4.02012199e-01, -6.25294745e-02, -2.05454119e-02],
#            [-5.04886359e-02, -9.01218597e-03, -9.25509110e-02, ...,
#             -5.01520783e-02,  7.14571625e-02, -1.40670324e-02],
#            [-9.97476131e-02, -2.90424544e-02, -5.35305440e-02, ...,
#             -1.24659322e-01,  1.94408387e-01, -9.44918171e-02]]]],
#
#
#
#         ...,
#
#
#
#         [[[[-1.89455878e-02, -1.06793754e-02,  7.58606493e-02, ...,
#              3.56562763e-01, -2.71800518e-01, -2.01967046e-01],
#            [ 3.77227105e-02, -2.72799209e-02,  3.36296670e-02, ...,
#             -5.83048165e-03,  1.53349027e-01, -1.80666208e-01],
#            [ 1.28718406e-01, -7.69504085e-02,  9.82168168e-02, ...,
#             -5.34770936e-02, -5.11132739e-02, -2.05834270e-01]],
#
#           [[ 2.37465188e-01, -4.03467715e-02,  1.07840255e-01, ...,
#              1.47974521e-01, -6.72427714e-02,  2.13862024e-02],
#            [ 2.70810544e-01, -4.60322127e-02,  5.45081757e-02, ...,
#             -6.57350868e-02,  6.16255291e-02,  7.30141923e-02],
#            [ 3.58521432e-01, -9.32302997e-02,  9.05091017e-02, ...,
#              3.70874070e-02, -1.32533878e-01,  6.66308030e-02]],
#
#           [[ 6.49539828e-02, -3.46398018e-02,  3.36851217e-02, ...,
#             -9.45071205e-02,  2.95028150e-01,  1.52608514e-01],
# ...
#            [-6.18664722e-04,  9.01959464e-03, -4.04503755e-02, ...,
#              1.50549086e-02, -2.96845920e-02, -2.28086822e-02]],
#
#           [[ 3.47168272e-04, -3.82102318e-02,  1.06957899e-02, ...,
#              2.26027388e-02, -1.02180354e-01, -4.29737866e-02],
#            [ 1.40413400e-02,  3.74365598e-02, -4.56515960e-02, ...,
#             -9.36238468e-03,  6.82764947e-02, -3.26276757e-02],
#            [ 1.41611043e-02, -9.61463060e-03, -9.52978954e-02, ...,
#              7.41494894e-02, -3.37643884e-02,  3.15000862e-02],
#            ...,
#            [ 8.41722140e-05, -9.51237604e-03,  9.57400426e-02, ...,
#              6.80621415e-02,  7.53757134e-02, -3.05418088e-03],
#            [ 7.01019764e-02, -5.77725656e-02,  5.75866401e-02, ...,
#             -1.18288957e-02,  5.78066893e-03, -6.69146553e-02],
#            [-4.32034861e-03, -1.08074360e-02, -4.15742360e-02, ...,
#              1.26570109e-02, -4.78882948e-03, -6.52959058e-03]],
#
#           [[-3.74976313e-03, -1.71684213e-02,  1.21789686e-02, ...,
#              2.86091864e-02, -6.18590564e-02, -2.61742696e-02],
#            [-1.24479020e-02,  3.32724638e-02, -3.57505456e-02, ...,
#             -1.17739532e-02,  5.66818267e-02, -3.37147303e-02],
#            [ 1.62119381e-02, -3.32152448e-03, -8.84476453e-02, ...,
#              7.76485875e-02, -4.04404774e-02,  2.09520701e-02],
#            ...,
#            [-1.14525631e-02, -8.08815751e-03,  1.38327882e-01, ...,
#              7.30310827e-02,  1.50016937e-02,  4.41913167e-03],
#            [ 3.35456617e-02, -4.10797484e-02,  3.37083973e-02, ...,
#             -2.02647671e-02,  2.74676755e-02, -3.88679393e-02],
#            [-1.99816408e-04, -3.80457635e-03, -2.09215358e-02, ...,
#              1.33569678e-02, -2.16961955e-03,  3.23303835e-03]]]],
#
#
#
#         [[[[-1.15802446e-02, -5.42157516e-03,  1.31548000e-02, ...,
#              2.42057559e-03, -9.53691527e-02, -3.56910713e-02],
#            [-2.04154588e-02, -1.31622620e-03,  1.12055195e-02, ...,
#             -1.64244603e-02,  1.43361628e-01,  2.91469414e-02],
#            [-2.42227763e-02, -7.00675230e-03, -7.39372447e-02, ...,
#              7.11667761e-02,  4.56324480e-02, -1.18315509e-02],
#            ...,
#            [-2.56837513e-02,  1.99038330e-02,  2.00371727e-01, ...,
#             -1.02146454e-02, -1.05502829e-03, -2.25830339e-02],
#            [ 6.57799616e-02, -1.83880888e-02,  7.99551308e-02, ...,
#              1.06678139e-02,  1.79340355e-02, -1.56049486e-02],
#            [ 3.85503247e-02,  8.18927959e-02, -7.55971298e-02, ...,
#             -4.30739224e-02, -1.61199644e-02, -3.56772356e-02]],
#
#           [[ 1.99275222e-02, -4.84120846e-03,  2.76435004e-03, ...,
#             -4.21639270e-04, -1.10790998e-01, -2.80852802e-02],
#            [-1.99721847e-02, -1.03711663e-02,  1.14073427e-02, ...,
#             -1.44856507e-02,  1.78332821e-01,  5.85238561e-02],
#            [-8.21094308e-03, -9.96209681e-03, -7.42439106e-02, ...,
#              8.85062739e-02,  5.00376560e-02, -2.06380617e-02],
#            ...,
#            [ 1.38604557e-02,  2.01431327e-02,  1.98422253e-01, ...,
#              3.33508961e-02,  2.94329096e-02, -1.69265084e-02],
#            [ 1.38213292e-01, -1.73744205e-02,  1.29333973e-01, ...,
#              6.48325868e-03,  4.13965397e-02, -1.16091408e-03],
#            [ 4.77564819e-02,  6.67709112e-02, -5.85780554e-02, ...,
#             -3.02689597e-02, -3.20361904e-03, -2.75272187e-02]],
#
#           [[-3.31452675e-02, -2.19908496e-03,  2.67907716e-02, ...,
#              6.36862172e-03, -8.53402317e-02, -2.69123856e-02],
#            [-3.19711827e-02,  7.73924263e-03,  1.26194162e-02, ...,
#              2.49772216e-03,  1.55169100e-01,  2.19989344e-02],
#            [-1.03703840e-02,  4.03820799e-04, -8.63751769e-02, ...,
#              8.36306214e-02,  4.31696139e-02, -1.04381647e-02],
#            ...,
#            [-8.18676222e-03,  3.75332572e-02,  2.18536273e-01, ...,
#              4.82836086e-03, -7.18271546e-03, -8.63619614e-03],
#            [ 2.81399768e-02, -2.10187538e-03,  7.03515634e-02, ...,
#              7.82194175e-03,  2.67056134e-02, -9.47974715e-03],
#            [ 3.93448249e-02,  6.60786107e-02, -5.17894700e-02, ...,
#             -2.37355232e-02, -3.27904988e-03, -9.88580287e-03]]],
#
#
#          [[[-2.47997586e-02, -1.84275955e-02,  2.73263622e-02, ...,
#              1.50540052e-02, -8.06668624e-02, -6.03468753e-02],
#            [-5.19615319e-03, -8.26281495e-03, -2.03397870e-02, ...,
#             -6.82812184e-03,  1.63978517e-01,  1.55254882e-02],
#            [ 1.64918508e-02, -7.93994125e-03, -1.00803398e-01, ...,
#              1.29691824e-01,  4.37689051e-02,  2.62924470e-02],
#            ...,
#            [ 8.95457901e-03,  9.74182319e-03,  1.37574598e-01, ...,
#              9.14705172e-02,  1.00505292e-01, -1.88995767e-02],
#            [ 8.63440260e-02, -3.97846922e-02,  1.22534335e-01, ...,
#             -3.14308517e-03,  5.60900941e-02, -9.41314921e-03],
#            [ 4.24132571e-02,  1.53040931e-01, -8.00249428e-02, ...,
#              5.07237203e-03, -1.41397808e-02, -3.44434083e-02]],
#
#           [[-1.03685148e-02, -3.08477636e-02,  2.51200143e-02, ...,
#              1.51665946e-02, -1.00010239e-01, -6.14216551e-02],
#            [-3.13424990e-02, -2.24212743e-03, -1.86333172e-02, ...,
#             -1.16696637e-02,  1.49895266e-01,  1.77128389e-02],
#            [ 1.12494659e-02, -1.16261225e-02, -1.03550725e-01, ...,
#              1.21868454e-01,  4.61902395e-02,  1.66355949e-02],
#            ...,
#            [ 2.56709196e-02, -4.04113205e-03,  8.06206763e-02, ...,
#              8.35201591e-02,  9.11523476e-02, -1.48814609e-02],
#            [ 1.05379075e-01, -3.19517553e-02,  1.25990242e-01, ...,
#              3.08945263e-03,  5.89536503e-02, -3.95843424e-02],
#            [ 2.48041134e-02,  8.93495083e-02, -3.88878882e-02, ...,
#              1.61990803e-02, -1.86501667e-02, -3.26088034e-02]],
#
#           [[-2.84730364e-02, -1.58208013e-02,  3.73992324e-02, ...,
#              2.66259536e-02, -7.47875348e-02, -4.75736484e-02],
#            [-3.83780263e-02,  4.73267864e-03, -2.05427296e-02, ...,
#             -1.23183560e-02,  1.51266426e-01, -7.14697363e-03],
#            [ 1.60513893e-02,  6.16797013e-04, -1.04742020e-01, ...,
#              1.29531711e-01,  3.05061322e-02,  3.02782916e-02],
#            ...,
#            [-3.35499877e-03,  1.31045775e-02,  1.17777802e-01, ...,
#              8.70349705e-02,  6.71420246e-02, -2.63693067e-03],
#            [ 5.54855838e-02, -2.41925791e-02,  1.01132207e-01, ...,
#              3.84191028e-03,  4.86870594e-02, -3.57269123e-02],
#            [ 3.53691913e-02,  1.14869528e-01, -3.38628441e-02, ...,
#             -4.03274735e-03, -1.63404457e-02, -2.07950845e-02]]],
#
#
#          [[[-1.82938166e-02, -1.53397890e-02,  5.11896797e-02, ...,
#              2.83081103e-02, -5.97673617e-02, -4.76663634e-02],
#            [-2.25995518e-02, -3.36361630e-03, -6.41480163e-02, ...,
#             -1.09069673e-02,  1.54576793e-01, -9.43422783e-03],
#            [ 1.11922352e-02, -1.83762237e-02, -9.73547995e-02, ...,
#              1.03274241e-01,  1.89602412e-02,  3.19333039e-02],
#            ...,
#            [-3.31712095e-03, -1.78020019e-02,  2.13069737e-01, ...,
#              4.88077626e-02,  6.92237392e-02, -2.04217304e-02],
#            [ 5.95383495e-02, -2.62737926e-02,  1.09851167e-01, ...,
#             -1.55861583e-02,  2.65481863e-02, -1.76327713e-02],
#            [ 1.13412151e-02,  5.91826923e-02, -5.05071320e-02, ...,
#              1.43668859e-03, -2.00822167e-02, -2.17272546e-02]],
#
#           [[-2.46160850e-02, -2.40838900e-02,  3.64445262e-02, ...,
#              2.44054142e-02, -9.17879865e-02, -4.83005494e-02],
#            [-4.69074063e-02,  4.29662829e-03, -5.40762693e-02, ...,
#             -2.45660022e-02,  1.59007668e-01, -1.49804270e-02],
#            [ 1.02455402e-02, -2.58945283e-02, -9.21498165e-02, ...,
#              1.18409805e-01,  1.60204358e-02,  2.31404137e-02],
#            ...,
#            [ 6.04575640e-03, -1.56957358e-02,  1.42411083e-01, ...,
#              6.53392598e-02,  9.05189738e-02, -2.64312252e-02],
#            [ 9.93725434e-02, -4.79957275e-02,  1.03395879e-01, ...,
#             -4.71902359e-03,  2.24932432e-02, -4.91820425e-02],
#            [ 1.26094194e-02,  2.50629243e-02, -5.11078760e-02, ...,
#              1.03509603e-02, -1.40272556e-02, -1.29967313e-02]],
#
#           [[-3.13332267e-02, -8.38275719e-03,  2.68940162e-02, ...,
#              2.01055836e-02, -5.71639240e-02, -4.16605361e-02],
#            [-5.93363196e-02,  8.17492697e-03, -4.33312058e-02, ...,
#             -1.31126847e-02,  1.16785511e-01, -2.89045218e-02],
#            [ 1.82940776e-03,  9.65007301e-03, -9.19804946e-02, ...,
#              1.22158788e-01, -1.23125501e-02,  2.65979376e-02],
#            ...,
#            [-1.14806155e-02, -2.57805232e-02,  1.41513661e-01, ...,
#              7.09051937e-02,  4.06639203e-02, -1.11193918e-02],
#            [ 4.02982756e-02, -3.11566405e-02,  4.38701287e-02, ...,
#             -9.70693585e-03,  3.20079438e-02, -4.18595374e-02],
#            [ 2.01298222e-02,  2.23172382e-02, -1.98187735e-02, ...,
#             -1.22678047e-03, -1.24160219e-02, -1.77291560e-03]]]]],
#        dtype=float32)>,
#  'Flow/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/batch_norm/beta': <tf.Variable 'Flow/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/batch_norm/beta:0' shape=(128,) dtype=float32, numpy=
#  array([-0.7055682 , -0.6186319 , -0.73657614, -0.6735541 , -0.685041  ,
#         -0.7242813 , -0.741205  , -0.57672435, -0.7077816 , -0.7195834 ,
#         -0.69304687, -0.6834984 , -0.608202  , -0.73024505, -0.7416492 ,
#         -0.6787687 , -0.71205914, -0.69564915, -0.70125735, -0.74995106,
#         -0.7081429 , -0.7752023 , -0.78141403, -0.6951948 , -0.5898892 ,
#         -0.69527996, -0.7613069 , -0.73906976, -0.5223305 , -0.6208316 ,
#         -0.70457053, -0.6735823 , -0.70580304, -0.63072467, -0.7233613 ,
#         -0.7219968 , -0.63881   , -0.6996081 , -0.65180004, -0.71460414,
#         -0.68981326, -0.72619474, -0.7652826 , -0.685738  , -0.69471616,
#         -0.6676191 , -0.62761396, -0.67429334, -0.7545571 , -0.7312863 ,
#         -0.67096734, -0.6691751 , -0.75559896, -0.68700165, -0.6562117 ,
#         -0.69192016, -0.6376833 , -0.6930178 , -0.66635543, -0.53520185,
#         -0.7480232 , -0.76460004, -0.6502201 , -0.70391387, -0.7071495 ,
#         -0.7423214 , -0.69165707, -0.56591004, -0.65694016, -0.7269203 ,
#         -0.55907506, -0.67970246, -0.7300699 , -0.6303624 , -0.7567347 ,
#         -0.65075344, -0.6957237 , -0.7665884 , -0.67221576, -0.70829   ,
#         -0.75725824, -0.6893287 , -0.7247899 , -0.691352  , -0.66837054,
#         -0.62825114, -0.6798582 , -0.5775214 , -0.71321803, -0.72094804,
#         -0.6448276 , -0.6798344 , -0.72971535, -0.67113537, -0.69167733,
#         -0.71870375, -0.7077665 , -0.72886497, -0.7255923 , -0.5540634 ,
#         -0.7187423 , -0.548959  , -0.71877444, -0.65232223, -0.6636922 ,
#         -0.66095257, -0.7027854 , -0.7396306 , -0.7312083 , -0.73337525,
#         -0.6266122 , -0.59162855, -0.75295013, -0.5849472 , -0.7507578 ,
#         -0.6575402 , -0.63601166, -0.55266714, -0.6827661 , -0.71391916,
#         -0.7795906 , -0.7145228 , -0.7106353 , -0.75096774, -0.7334218 ,
#         -0.7483515 , -0.7340674 , -0.69935286], dtype=float32)>,
#  'Flow/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean': <tf.Variable 'Flow/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_mean:0' shape=(128,) dtype=float32, numpy=
#  array([ 1.7363312 ,  0.5037703 , -0.44824907, -0.94378316,  0.5139441 ,
#          1.2177614 ,  0.4950432 , -0.47494563,  0.32076582,  0.7896216 ,
#         -1.0396814 ,  1.2343237 , -0.6877638 ,  1.3857052 ,  0.44768935,
#         -0.08163791,  0.5722363 ,  0.8910756 , -1.4513164 ,  1.3097779 ,
#          1.8607187 ,  0.7673435 ,  0.93362033,  0.02014169, -0.19310956,
#         -0.29193404, -0.667505  , -0.20564035, -1.6982527 ,  0.03978523,
#          0.02797899, -0.73185134, -0.8954398 , -1.3862628 , -0.8187715 ,
#          0.6551802 , -1.6785145 , -0.06381034, -1.7544504 ,  0.21168931,
#          0.704972  ,  0.22648795,  1.151759  ,  1.083099  , -0.11836831,
#          0.17334607,  1.3033459 , -0.02495759, -0.6102867 , -0.3314958 ,
#          0.49401897,  0.19904266,  1.215871  ,  0.41288692, -0.5737824 ,
#         -0.34245348,  0.8893453 , -2.318025  ,  0.97055906,  0.65425754,
#          0.45630312, -0.49888912,  0.75429213,  0.90954906,  1.2174134 ,
#          0.04140039, -0.12120018,  0.2603582 ,  0.30072337,  0.69611394,
#         -0.4377439 ,  0.56740606,  0.33606315, -0.2955785 , -0.2203102 ,
#         -0.37251055, -0.21093573, -0.59385437, -0.7572067 , -0.09796312,
#          0.2958726 , -0.51838034, -0.75610816, -0.8618508 , -0.9711832 ,
#          0.8366466 , -0.3692235 , -0.43519005,  0.5679223 , -0.42530686,
#          0.3786559 , -0.36749935,  0.4402773 ,  0.3669638 , -0.00792693,
#          0.36644563, -0.42124677,  0.72596884, -0.8782727 , -0.23448332,
#         -0.89240307,  1.0534073 ,  0.6604668 , -0.31615496, -0.37343603,
#         -0.08296694, -0.4068433 , -0.5717286 ,  1.1166734 ,  0.59936386,
#         -1.1553206 ,  0.81048334,  0.05949872,  0.20323133,  0.8868097 ,
#         -0.25553355,  0.09396059, -0.41011047,  1.8220775 , -0.24282196,
#          0.83643645, -0.06075006, -0.3785599 , -1.167547  ,  0.02218765,
#          0.8519455 ,  1.4812707 , -0.32417402], dtype=float32)>,
#  'Flow/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance': <tf.Variable 'Flow/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/batch_norm/moving_variance:0' shape=(128,) dtype=float32, numpy=
#  array([4.9523044, 4.6339035, 5.3785167, 4.8403554, 5.0550284, 5.101507 ,
#         4.8360257, 6.150781 , 5.11835  , 5.578181 , 5.1364856, 5.224105 ,
#         6.148749 , 4.687171 , 4.976477 , 5.461334 , 4.701988 , 5.3000894,
#         5.065208 , 4.911195 , 5.2459664, 4.615436 , 4.7413044, 5.451992 ,
#         6.483005 , 4.9449487, 5.626707 , 5.193464 , 8.500773 , 4.414387 ,
#         5.300349 , 5.075664 , 5.1619806, 6.0554886, 5.274109 , 4.863517 ,
#         5.2586374, 5.139784 , 5.3740945, 4.6580973, 5.110147 , 5.205536 ,
#         5.326022 , 5.2767043, 5.194979 , 5.2211623, 6.4532638, 4.9703026,
#         5.1296425, 4.673574 , 5.594233 , 4.839492 , 4.6575913, 6.1744223,
#         5.240587 , 5.005654 , 5.904301 , 5.175588 , 5.432798 , 6.589366 ,
#         4.910789 , 5.301213 , 5.060289 , 4.7292314, 5.036064 , 4.9529057,
#         5.694579 , 8.212767 , 5.189935 , 5.0357423, 7.475719 , 5.045746 ,
#         5.079594 , 5.345824 , 5.1657944, 4.8345914, 4.990366 , 4.807635 ,
#         5.577226 , 5.3107457, 5.083785 , 5.216875 , 5.3072896, 5.425123 ,
#         5.4558306, 4.2887177, 5.2735047, 5.446134 , 5.3388844, 5.116027 ,
#         5.046327 , 4.8260384, 4.825136 , 4.925412 , 5.134392 , 5.1738486,
#         4.9266343, 4.8888817, 5.1950946, 6.6482296, 4.9684973, 7.6802197,
#         4.8885365, 5.1778307, 4.9773145, 4.730034 , 5.0167193, 4.858292 ,
#         5.3484316, 5.2033253, 5.436207 , 5.78773  , 5.03352  , 5.8393564,
#         4.822814 , 4.8277807, 5.007312 , 9.06438  , 4.3723435, 5.1209984,
#         4.8502026, 5.16356  , 5.546708 , 4.6323442, 5.444792 , 4.6907578,
#         5.020902 , 5.347221 ], dtype=float32)>,
#  'Flow/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/conv_3d/w': <tf.Variable 'Flow/inception_i3d/Mixed_5c/Branch_3/Conv3d_0b_1x1/conv_3d/w:0' shape=(1, 1, 1, 832, 128) dtype=float32, numpy=
#  array([[[[[ 0.07123375,  0.02386325, -0.08071427, ...,  0.03300237,
#              0.17833504,  0.0796054 ],
#            [-0.10148019, -0.11858962,  0.23796462, ...,  0.0424207 ,
#             -0.340784  ,  0.06399874],
#            [ 0.01983667, -0.0693953 , -0.1591755 , ...,  0.01001826,
#              0.21851662, -0.13073076],
#            ...,
#            [-0.0131912 ,  0.08400997,  0.2439871 , ...,  0.14476591,
#             -0.02716329,  0.1305975 ],
#            [-0.10925067,  0.05297009, -0.00746335, ..., -0.15985684,
#              0.2703607 ,  0.14377317],
#            [ 0.03402352, -0.12160953,  0.022969  , ..., -0.22392412,
#             -0.09416725,  0.05868431]]]]], dtype=float32)>}

# %%
_NUM_CLASSES = 400 # size of the output ('logits') layer
rgb_model = InceptionI3d(var_prefix='RGB', num_classes=_NUM_CLASSES, spatial_squeeze=True, final_endpoint='Logits')
flow_model = InceptionI3d(var_prefix='Flow', num_classes=_NUM_CLASSES, spatial_squeeze=True, final_endpoint='Logits')

# %%
# the provided sample data to test the network. the expected output is recorded in i3d/out. as you'll see it varies
# slightly from what I obtain here. it's possible some part of the network is incorrectly configured.
cricket_sample_rgb = np.load("i3d/data/v_CricketShot_g04_c01_rgb.npy")
cricket_sample_flow = np.load("i3d/data/v_CricketShot_g04_c01_flow.npy")
results_rgb = rgb_model(cricket_sample_rgb, False)
results_flow = flow_model(cricket_sample_flow, False)

# %%
rgb_logits = results_rgb[0][0] 
flow_logits = results_flow[0][0]
# the ensemble is defined by averaging the logits of the two nets
joint_logits = rgb_logits+flow_logits
rgb_predictions= tf.nn.softmax(rgb_logits)
flow_predictions = tf.nn.softmax(flow_logits)
joint_predictions = tf.nn.softmax(joint_logits)

# %%
print('RGB logits norm: ', np.linalg.norm(rgb_logits))
sorted_indices = np.argsort(rgb_predictions)[::-1]
print('\nTop classes and probabilities')
for index in sorted_indices[:20]:
    print(rgb_predictions[index].numpy(), rgb_logits[index].numpy(), kinetics_classes[index])
# Out:
# RGB logits norm:  82.22748
#
# Top classes and probabilities
# 0.99999356 24.439657 playing cricket
# 1.867471e-06 11.248738 playing kickball
# 1.0207867e-06 10.644727 catching or throwing baseball
# 7.317671e-07 10.31186 shooting goal (soccer)
# 3.890843e-07 9.680194 catching or throwing softball
# 2.9659031e-07 9.40875 throwing discus
# 2.812762e-07 9.355735 golf putting
# 2.2379594e-07 9.127132 javelin throw
# 1.8174018e-07 8.918976 hitting baseball
# 1.6635353e-07 8.830513 jogging
# 1.5847925e-07 8.7820215 triple jump
# 9.767191e-08 8.298012 hurling (sport)
# 7.101792e-08 7.97933 skateboarding
# 5.3876825e-08 7.703098 playing tennis
# 5.086984e-08 7.645668 golf driving
# 4.8518956e-08 7.598353 breakdancing
# 4.6196377e-08 7.5492992 hurdling
# 4.388894e-08 7.49806 shot put
# 4.2333035e-08 7.4619656 hammer throw
# 4.1440746e-08 7.440663 headbutting

# %%
print('Flow logits norm: ', np.linalg.norm(flow_logits))
sorted_indices = np.argsort(flow_predictions)[::-1]
print('\nTop classes and probabilities')
for index in sorted_indices[:20]:
    print(flow_predictions[index].numpy(), flow_logits[index].numpy(), kinetics_classes[index])
# Out:
# Flow logits norm:  60.69956
#
# Top classes and probabilities
# 0.93996334 15.352985 playing cricket
# 0.047061183 12.358593 hurling (sport)
# 0.00417177 9.935485 playing tennis
# 0.002486601 9.418061 playing squash or racquetball
# 0.0018447473 9.119487 hitting baseball
# 0.0010174264 8.524421 catching or throwing baseball
# 0.0008785112 8.377618 sword fighting
# 0.00086664734 8.364021 catching or throwing softball
# 0.00031376272 7.3480268 hammer throw
# 0.00023573413 7.0620937 playing badminton
# 8.246747e-05 6.0117936 tai chi
# 8.0938684e-05 5.993081 pumping fist
# 5.786033e-05 5.657421 training dog
# 5.1758932e-05 5.545986 golf putting
# 5.0176906e-05 5.5149436 catching or throwing frisbee
# 4.6635956e-05 5.441761 shot put
# 4.3011554e-05 5.360858 celebrating
# 4.06844e-05 5.305234 throwing ball
# 3.935577e-05 5.2720323 pole vault
# 3.292958e-05 5.0937605 shooting goal (soccer)

# %%
print('Joint logits norm: ', np.linalg.norm(joint_logits))
sorted_indices = np.argsort(joint_predictions)[::-1]
print('\nTop classes and probabilities')
for index in sorted_indices[:20]:
    print(joint_predictions[index].numpy(), joint_logits[index].numpy(), kinetics_classes[index])
# Out:
# Joint logits norm:  131.71538
#
# Top classes and probabilities
# 1.0 39.79264 playing cricket
# 4.8901843e-09 20.656605 hurling (sport)
# 1.1049197e-09 19.169147 catching or throwing baseball
# 3.5873954e-10 18.044216 catching or throwing softball
# 3.566818e-10 18.038464 hitting baseball
# 2.391193e-10 17.638582 playing tennis
# 5.1048447e-11 16.094395 playing kickball
# 3.053473e-11 15.580484 playing squash or racquetball
# 2.5636087e-11 15.405621 shooting goal (soccer)
# 1.548857e-11 14.901721 golf putting
# 1.4131018e-11 14.809992 hammer throw
# 6.6411768e-12 14.054908 throwing discus
# 6.531621e-12 14.038275 javelin throw
# 2.7994696e-12 13.19105 pumping fist
# 2.1775526e-12 12.939821 shot put
# 1.7227076e-12 12.705517 celebrating
# 1.4000173e-12 12.498103 applauding
# 7.030067e-13 11.80923 throwing ball
# 5.100975e-13 11.488466 dodgeball
# 4.9124886e-13 11.450815 breakdancing
